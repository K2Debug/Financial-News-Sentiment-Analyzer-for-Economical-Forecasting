# %%
import os
from pathlib import Path

PROJECT_ROOT = Path("/content/EF-02")
NOTEBOOKS_DIR = PROJECT_ROOT / "notebooks"

if PROJECT_ROOT.exists():
    os.chdir(NOTEBOOKS_DIR)
else:
    raise RuntimeError(
        "Error: Project folder not found. Please open and run '00_setup.ipynb' first "
        "to initialize the local workspace before running this pipeline step."
    )

# %% [markdown]
# ## Section 1: Setup

# %%
import pandas as pd
import json
import time
import re
from groq import Groq
from dotenv import load_dotenv
import os

load_dotenv()

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

MODEL = "llama-3.1-8b-instant"
BATCH_SIZE = 25
SLEEP_SEC  = 1.5

VALID_CATEGORIES = {
    "Forex", "Policy", "Banking", "Trade",
    "Agriculture", "Energy", "Transport", "Investment",
    "Markets", "Tourism", "Inflation"
}
VALID_SENTIMENTS = {"Positive", "Negative", "Neutral"}

# %% [markdown]
# ## Section 2: Prompt

# %%
SYSTEM_PROMPT = """You are a financial news classifier for Tanzania.
You return ONLY a valid JSON array. No preamble, no explanation, no markdown fences.
Every object in the array must be complete and the array must be properly closed with ]."""


def build_prompt(batch, include_reason=False):
    lines = "\n".join(
        f"{i+1}. {item['headline']}"
        for i, item in enumerate(batch)
    )

    reason_field = ""
    if include_reason:
        reason_field = '\nAdd "reason": 4-6 words explaining your decision (debugging only).'

    return f"""You classify Tanzanian financial headlines. Output ONLY a valid JSON array.

Schema: [{{"pos":1,"relevant":true,"category":"Forex","sentiment":"Positive"}}, ...]{reason_field}

STEP 0 — RELEVANCE:
relevant true → Tanzania economy, finance, business, trade, banking, currency, energy, agriculture
relevant false → sports, crime, entertainment, foreign-only news, opinion/lifestyle; if false set category/sentiment null

STEP 1 — pick ONE category:
Forex(shilling,dollar,reserves) | Policy(BOT,IMF,budget,tax,debt,GDP,NBS,rates) | Banking(banks,loans,fintech,insurance) | Trade(imports,exports,tariffs,ports,AfCFTA) | Agriculture(crops,farming,food) | Energy(TANESCO,fuel,power) | Transport(SGR,rail,roads,logistics) | Investment(FDI,factories,PPP,crowdfunding) | Markets(DSE,CMSA,equity,bonds,turnover) | Tourism(hotels,arrivals) | Inflation(CPI,food/cement price spikes)

Disambiguation: DSE/CMSA→Markets | BOT rate/GDP→Policy | food/cement price spike→Inflation | hotels→Tourism

STEP 2 — SENTIMENT (economic outcome not tone):
Positive=growth,profit up,shilling firms,easing inflation,launches | Negative=decline,loss,miss target,weakening,rising inflation | Neutral=steady,guidelines,reviews,no clear direction
Falling inflation=Positive. Rising inflation=Negative.

Headlines:
{lines}"""

# %% [markdown]
# ## Section 3: Test Run
# Runs on a sample with `reason` off by default. Use `include_reason=True` only when inspecting individual decisions.

# %%
def classify_batch(batch, batch_num, total_batches, include_reason=False, max_retries=3):
    prompt = build_prompt(batch, include_reason=include_reason)
    raw = ""

    for attempt in range(1, max_retries + 1):
        try:
            response = client.chat.completions.create(
                model=MODEL,
                messages=[
                    {"role": "system", "content": SYSTEM_PROMPT},
                    {"role": "user",   "content": prompt}
                ],
                temperature=0,
                max_tokens=2500
            )

            raw   = response.choices[0].message.content.strip()
            clean = re.sub(r'```(?:json)?|```', '', raw).strip()
            parsed = json.loads(clean)

            if not isinstance(parsed, list):
                raise ValueError(f"Expected list, got {type(parsed)}")
            if len(parsed) != len(batch):
                raise ValueError(f"Got {len(parsed)} results for {len(batch)} headlines")

            for i, result in enumerate(parsed):
                result['id'] = batch[i]['id']
                result.pop('pos', None)

            print(f"  Batch {batch_num}/{total_batches} — OK ({len(parsed)} results)", end="\r", flush=True)
            return parsed

        except json.JSONDecodeError:
            tail = raw[-80:] if len(raw) > 80 else raw
            print(f"  Batch {batch_num} attempt {attempt}: JSON cut off. Ends: ...{repr(tail)}")
            time.sleep(2)

        except ValueError as e:
            print(f"  Batch {batch_num} attempt {attempt}: Validation error — {e}")
            time.sleep(2)

        except Exception as e:
            print(f"  Batch {batch_num} attempt {attempt}: API error — {e}")
            time.sleep(5)

    print(f"  Batch {batch_num}: FAILED after {max_retries} attempts. Filling with None.")
    return [
        {"id": item['id'], "relevant": None, "category": None, "sentiment": None}
        for item in batch
    ]


def run_classifier(input_csv, output_csv, batch_size=BATCH_SIZE,
                   test_size=None, include_reason=False):
    df = pd.read_csv(input_csv, engine='python', on_bad_lines='warn')
    print(f"Loaded: {len(df)} rows from {input_csv}")

    if test_size and test_size < len(df):
        df = df.sample(n=test_size, random_state=42).reset_index(drop=True)
        print(f"Sampled: {len(df)} rows for testing")
    else:
        df = df.reset_index(drop=True)
        print(f"Running on full dataset: {len(df)} rows")

    df['id'] = df.index

    rows    = df[['id', 'headline']].to_dict('records')
    batches = [rows[i:i+batch_size] for i in range(0, len(rows), batch_size)]
    total   = len(batches)
    print(f"\n{total} batches of up to {batch_size} headlines each")
    print(f"Estimated time: ~{total * SLEEP_SEC / 60:.1f} minutes\n")

    all_results = []
    for batch_num, batch in enumerate(batches, start=1):
        results = classify_batch(batch, batch_num, total, include_reason=include_reason)
        all_results.extend(results)
        if batch_num < total:
            time.sleep(SLEEP_SEC)

    df_results = pd.DataFrame(all_results)
    df_out     = df.merge(df_results, on='id', how='left').drop(columns=['id'])

    # Print summary
    total_rows = len(df_out)
    n_rel      = df_out['relevant'].sum()
    n_failed   = df_out['relevant'].isna().sum()

    print(f"\n{'='*50}")
    print(f"DONE")
    print(f"{'='*50}")
    print(f"  Total rows   : {total_rows}")
    print(f"  Relevant     : {int(n_rel)} ({n_rel/total_rows*100:.1f}%)")
    print(f"  Irrelevant   : {int(total_rows - n_rel)} ({(total_rows - n_rel)/total_rows*100:.1f}%)")
    if n_failed:
        print(f"  Failed rows  : {int(n_failed)} — run Section 5 retry cell to fix")

    print(f"\n  Category breakdown (relevant only):")
    for cat, count in df_out[df_out['relevant'] == True]['category'].value_counts().items():
        print(f"    {cat:<14} {count}")

    print(f"\n  Sentiment breakdown (relevant only):")
    for sent, count in df_out[df_out['relevant'] == True]['sentiment'].value_counts().items():
        print(f"    {sent:<14} {count}")

    df_out.to_csv(output_csv, index=False)
    print(f"\nSaved to {output_csv}")

    return df_out

# %%
# Test run — 300 headlines, batch size 10, no reason field
df_test = run_classifier(
    input_csv      = "../data/processed/tz_headlines_clean.csv",
    output_csv     = "../data/processed/tz_headlines_test.csv",
    test_size      = 300,
    include_reason = False
)
# Out:
# Loaded: 6235 rows from ../data/processed/tz_headlines_clean.csv
# Sampled: 300 rows for testing
#
# 12 batches of up to 25 headlines each
# Estimated time: ~0.3 minutes
#
#   Batch 5 attempt 1: API error — Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01kr3gec7df7fry1jtsm9rp8gk` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499362, Requested 3237. Please try again in 7m29.1072s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
#   Batch 5 attempt 2: API error — Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01kr3gec7df7fry1jtsm9rp8gk` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499331, Requested 1203. Please try again in 1m32.2752s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[17], line 7, in classify_batch(batch, batch_num, total_batches, include_reason, max_retries)
#       6 try:
# ----> 7     response = client.chat.completions.create(
#       8         model=MODEL,
#       9         messages=[
#      10             {"role": "system", "content": SYSTEM_PROMPT},
#      11             {"role": "user",   "content": prompt}
#      12         ],
#      13         temperature=0,
#      14         max_tokens=2500
#      15     )
#      17     raw   = response.choices[0].message.content.strip()
#
# File ~\anaconda3\Lib\site-packages\groq\resources\chat\completions.py:461, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     302 """
#     303 Creates a model response for the given chat conversation.
#     304
#    (...)    459   timeout: Override the client-level default timeout for this request, in seconds
#     460 """
# --> 461 return self._post(
#     462     "/openai/v1/chat/completions",
#     463     body=maybe_transform(
#     464         {
#     465             "messages": messages,
#     466             "model": model,
#     467             "citation_options": citation_options,
#     468             "compound_custom": compound_custom,
#     469             "disable_tool_validation": disable_tool_validation,
#     470             "documents": documents,
#     471             "exclude_domains": exclude_domains,
#     472             "frequency_penalty": frequency_penalty,
#     473             "function_call": function_call,
#     474             "functions": functions,
#     475             "include_domains": include_domains,
#     476             "include_reasoning": include_reasoning,
#     477             "logit_bias": logit_bias,
#     478             "logprobs": logprobs,
#     479             "max_completion_tokens": max_completion_tokens,
#     480             "max_tokens": max_tokens,
#     481             "metadata": metadata,
#     482             "n": n,
#     483             "parallel_tool_calls": parallel_tool_calls,
#     484             "presence_penalty": presence_penalty,
#     485             "reasoning_effort": reasoning_effort,
#     486             "reasoning_format": reasoning_format,
#     487             "response_format": response_format,
#     488             "search_settings": search_settings,
#     489             "seed": seed,
#     490             "service_tier": service_tier,
#     491             "stop": stop,
#     492             "store": store,
#     493             "stream": stream,
#     494             "temperature": temperature,
#     495             "tool_choice": tool_choice,
#     496             "tools": tools,
#     497             "top_logprobs": top_logprobs,
#     498             "top_p": top_p,
#     499             "user": user,
#     500         },
#     501         completion_create_params.CompletionCreateParams,
#     502     ),
#     503     options=make_request_options(
#     504         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     505     ),
#     506     cast_to=ChatCompletion,
#     507     stream=stream or False,
#     508     stream_cls=Stream[ChatCompletionChunk],
#     509 )
#
# File ~\anaconda3\Lib\site-packages\groq\_base_client.py:1284, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1281 opts = FinalRequestOptions.construct(
#    1282     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1283 )
# -> 1284 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\Lib\site-packages\groq\_base_client.py:1071, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1070     log.debug("Re-raising status error")
# -> 1071     raise self._make_status_error_from_response(err.response) from None
#    1073 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01kr3gec7df7fry1jtsm9rp8gk` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499331, Requested 1203. Please try again in 1m32.2752s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Test run — 300 headlines, batch size 10, no reason field
# ----> 2 df_test = run_classifier(
#       3     input_csv      = "../data/processed/tz_headlines_clean.csv",
#       4     output_csv     = "../data/processed/tz_headlines_test.csv",
#       5     test_size      = 300,
#       6     include_reason = False
#       7 )
#
# Cell In[17], line 75, in run_classifier(input_csv, output_csv, batch_size, test_size, include_reason)
#      73 all_results = []
#      74 for batch_num, batch in enumerate(batches, start=1):
# ---> 75     results = classify_batch(batch, batch_num, total, include_reason=include_reason)
#      76     all_results.extend(results)
#      77     if batch_num < total:
#
# Cell In[17], line 44, in classify_batch(batch, batch_num, total_batches, include_reason, max_retries)
#      42     except Exception as e:
#      43         print(f"  Batch {batch_num} attempt {attempt}: API error — {e}")
# ---> 44         time.sleep(5)
#      46 print(f"  Batch {batch_num}: FAILED after {max_retries} attempts. Filling with None.")
#      47 return [
#      48     {"id": item['id'], "relevant": None, "category": None, "sentiment": None}
#      49     for item in batch
#      50 ]
#
# KeyboardInterrupt:

# %%
# Inspect test results
df_test[df_test["relevant"]==False][["headline", "reason"]]
# Out:
#                                               headline  \
# 33   Tanzania's Taifa Gas licensed to set up plant ...
# 38   EAC plans to host Africa, China – US business ...
# 49   Fraud claims wipe $45 billion off India's Adan...
# 63   Saudia celebrates Arabia’s 2034 FIFA WC Win wi...
# 135  Don’t be afraid of not taking a well-trodden p...
# 140    China locks out Kenya from new debt relief deal
# 141                             State restore normalcy
# 142  The untold story of the making of Tanganyika -...
# 147          Tasks ahead for new Vodacom Tanzania boss
# 149        What future has in store for local startups
# 150  EXCLUSIVE:Samia on her year in office, the future
# 152  Students urged to deepen knowledge of intellec...
# 153  ‘Let’s focus on sectors  with competitive adva...
# 154  Stakeholders call for more safe, clean and sus...
# 159  Expert insights on Tanzania’s personal, busine...
# 165  Airtel, Indian discuss stretching technology i...
# 169  Lack of capital, business skills hinder women ...
# 170  The difficult choice: Domestic versus foreign ...
# 174  Tasks ahead of Ndayishimiye as the chairman of...
# 208  Here’s PM Majaliwa advice to Tanzanian diaspor...
# 209  ‘Mwanamke Shujaa’ hits ground running in Zanzibar
# 213        Public urged to adopt smart shopping habits
# 221  Njombe RC campaigns for ‘Tanzania can feed Afr...
# 263  Traditional foods shine at World Food Day in B...
# 273      Magufuli bus terminal a home for the homeless
# 276  Dirty swimming pools expose swimmers to diseas...
# 277       Simba cement standout performer stock on DSE
# 285  Minister gives TBS seven-day to table fate of ...
# 298  WALKING THE TALK: High expectations as MV Mwan...
# 299  Utilise technological opportunities to improve...
#
#                                                 reason
# 33                no clear Tanzanian financial content
# 38                no clear Tanzanian financial content
# 49                no clear Tanzanian financial content
# 63                             no clear economic theme
# 135  Don’t be afraid of not taking a well-trodden p...
# 140    China locks out Kenya from new debt relief deal
# 141                             State restore normalcy
# 142  The untold story of the making of Tanganyika -...
# 147          Tasks ahead for new Vodacom Tanzania boss
# 149        What future has in store for local startups
# 150                      No economic content mentioned
# 152                      No economic content mentioned
# 153                      No economic content mentioned
# 154                      No economic content mentioned
# 159                      No economic content mentioned
# 165                      No economic content mentioned
# 169                      No economic content mentioned
# 170                      No economic content mentioned
# 174                      No economic content mentioned
# 208                      No economic content mentioned
# 209                      No economic content mentioned
# 213                      No economic content mentioned
# 221                      No economic content mentioned
# 263          traditional foods shine at World Food Day
# 273      Magufuli bus terminal a home for the homeless
# 276                                  no economic topic
# 277                                  no economic topic
# 285                                  no economic topic
# 298                                  no economic topic
# 299                                  no economic topic

# %% [markdown]
# ## Section 4: Production Run
# Full dataset, `reason` field OFF. Run only when happy with test results.

# %%
# Production run — full dataset, no reason field
df_labelled = run_classifier(
    input_csv      = "../data/processed/tz_headlines_clean.csv",
    output_csv     = "../data/processed/tz_headlines_labelled.csv",
    include_reason = False
)
# Out:
# Loaded: 5310 rows from ../data/processed/tz_headlines_clean.csv
# Running on full dataset: 5310 rows
#
# 213 batches of up to 25 headlines each
# Estimated time: ~5.3 minutes
#
#   Batch 3 attempt 1: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "Banking",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 3 attempt 2: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "Banking",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 3 attempt 3: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "Banking",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 3: FAILED after 3 attempts. Filling with None.
#   Batch 6 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 6 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 6 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 6: FAILED after 3 attempts. Filling with None.
#   Batch 21 attempt 1: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 21 attempt 2: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 21 attempt 3: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 21: FAILED after 3 attempts. Filling with None.
#   Batch 24 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 24 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 24 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 24: FAILED after 3 attempts. Filling with None.
#   Batch 30 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 30 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 30 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 30: FAILED after 3 attempts. Filling with None.
#   Batch 37 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 37 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 37 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 37: FAILED after 3 attempts. Filling with None.
#   Batch 50 attempt 1: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 50 attempt 2: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 50 attempt 3: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 50: FAILED after 3 attempts. Filling with None.
#   Batch 66 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 66 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 66 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 66: FAILED after 3 attempts. Filling with None.
#   Batch 70 attempt 1: JSON cut off. Ends: ...'\n    "relevant": true,\n    "category": "Trade",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 70 attempt 2: JSON cut off. Ends: ...'\n    "relevant": true,\n    "category": "Trade",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 70 attempt 3: JSON cut off. Ends: ...'\n    "relevant": true,\n    "category": "Trade",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 70: FAILED after 3 attempts. Filling with None.
#   Batch 80 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 80 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 80 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 80: FAILED after 3 attempts. Filling with None.
#   Batch 109 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 109 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 109 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 109: FAILED after 3 attempts. Filling with None.
#   Batch 120 attempt 1: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "General",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 120 attempt 2: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "General",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 120 attempt 3: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "General",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 120: FAILED after 3 attempts. Filling with None.
#   Batch 126 attempt 1: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "Policy",\n    "sentiment": "Positive"\n  ]\n]'
#   Batch 126 attempt 2: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "Policy",\n    "sentiment": "Positive"\n  ]\n]'
#   Batch 126 attempt 3: JSON cut off. Ends: ...'   "relevant": true,\n    "category": "Policy",\n    "sentiment": "Positive"\n  ]\n]'
#   Batch 126: FAILED after 3 attempts. Filling with None.
#   Batch 134 attempt 1: JSON cut off. Ends: ...'    "relevant": true,\n    "category": "Policy",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 134 attempt 2: JSON cut off. Ends: ...'    "relevant": true,\n    "category": "Policy",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 134 attempt 3: JSON cut off. Ends: ...'    "relevant": true,\n    "category": "Policy",\n    "sentiment": "Neutral"\n  ]\n]'
#   Batch 134: FAILED after 3 attempts. Filling with None.
#   Batch 142 attempt 1: JSON cut off. Ends: ...' "pos": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n]'
#   Batch 142 attempt 2: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 142 attempt 3: JSON cut off. Ends: ...'s": 25,\n    "relevant": false,\n    "category": null,\n    "sentiment": null\n  ]\n]'
#   Batch 142: FAILED after 3 attempts. Filling with None.
#   Batch 162 attempt 1: Validation error — Got 1 results for 25 headlines
#   Batch 162 attempt 2: Validation error — Got 1 results for 25 headlines
#   Batch 162 attempt 3: Validation error — Got 1 results for 25 headlines
#   Batch 162: FAILED after 3 attempts. Filling with None.
#   Batch 213/213 — OK (10 results)
# ==================================================
# DONE
# ==================================================
#   Total rows   : 5310
#   Relevant     : 3536 (66.6%)
#   Irrelevant   : 1774 (33.4%)
#   Failed rows  : 400 — run Section 5 retry cell to fix
#
#   Category breakdown (relevant only):
#     Banking        719
#     Trade          543
#     Agriculture    540
#     General        510
#     Policy         465
#     Investment     386
#     Energy         159
#     Forex          114
#     Transport      95
#     Tourism        3
#     Mining         2
#
#   Sentiment breakdown (relevant only):
#     Neutral        2238
#     Positive       994
#     Negative       303
#
# Saved to ../data/processed/tz_headlines_labelled.csv

# %% [markdown]
# ## Section 5: Retry
# Targets only rows where classification failed (relevant is NaN). Uses smaller batches to avoid token overflow.

# %%
LABELLED_CSV = "../data/processed/tz_headlines_labelled.csv"

df_full   = pd.read_csv(LABELLED_CSV)
df_failed = df_full[df_full['relevant'].isna()].copy().reset_index(drop=True)
print(f"Found {len(df_failed)} failed rows to retry")

if len(df_failed) == 0:
    print("Nothing to retry — all rows classified.")
else:
    df_failed['id'] = df_failed.index

    rows    = df_failed[['id', 'headline']].to_dict('records')
    batches = [rows[i:i+BATCH_SIZE] for i in range(0, len(rows), BATCH_SIZE)]
    total   = len(batches)
    print(f"{total} retry batches of up to {BATCH_SIZE} headlines each\n")

    retry_results = []
    for batch_num, batch in enumerate(batches, start=1):
        results = classify_batch(batch, batch_num, total, include_reason=False)
        retry_results.extend(results)
        if batch_num < total:
            time.sleep(SLEEP_SEC)

    # Patch results back into the full dataframe
    df_retry = pd.DataFrame(retry_results).drop(columns=['id'])
    failed_idx = df_full[df_full['relevant'].isna()].index
    df_full.loc[failed_idx, ['relevant', 'category', 'sentiment']] = \
        df_retry[['relevant', 'category', 'sentiment']].values

    still_failed = df_full['relevant'].isna().sum()
    print(f"\nRetry complete. Still failed: {int(still_failed)} rows")

    df_full.to_csv(LABELLED_CSV, index=False)
    print(f"Saved patched file to {LABELLED_CSV}")
# Out:
# Found 400 failed rows to retry
# 40 retry batches of up to 10 headlines each
#
#   Batch 40/40 — OK (10 results)
# Retry complete. Still failed: 0 rows
# Saved patched file to ../data/processed/tz_headlines_labelled.csv

# %%
def summary(df):
    total_rows = len(df)
    n_rel      = df['relevant'].sum()
    n_failed   = df['relevant'].isna().sum()
    
    print(f"\n{'='*50}")
    print(f"DONE")
    print(f"{'='*50}")
    print(f"  Total rows   : {total_rows}")
    print(f"  Relevant     : {int(n_rel)} ({n_rel/total_rows*100:.1f}%)")
    print(f"  Irrelevant   : {int(total_rows - n_rel)} ({(total_rows - n_rel)/total_rows*100:.1f}%)")
    if n_failed:
        print(f"  Failed rows  : {int(n_failed)} — run Section 5 retry cell to fix")
    
    print(f"\n  Category breakdown (relevant only):")
    for cat, count in df[df['relevant'] == True]['category'].value_counts().items():
        print(f"    {cat:<14} {count}")
    
    print(f"\n  Sentiment breakdown (relevant only):")
    for sent, count in df[df['relevant'] == True]['sentiment'].value_counts().items():
        print(f"    {sent:<14} {count}")


df_summary = pd.read_csv("../data/processed/tz_headlines_labelled.csv")
summary(df_summary)
# Out:
# ==================================================
# DONE
# ==================================================
#   Total rows   : 5310
#   Relevant     : 3836 (72.2%)
#   Irrelevant   : 1474 (27.8%)
#
#   Category breakdown (relevant only):
#     Banking        785
#     Agriculture    593
#     Trade          580
#     General        551
#     Policy         508
#     Investment     420
#     Energy         173
#     Forex          119
#     Transport      101
#     Tourism        3
#     Mining         2
#     Inflation      1
#
#   Sentiment breakdown (relevant only):
#     Neutral        2398
#     Positive       1114
#     Negative       323
