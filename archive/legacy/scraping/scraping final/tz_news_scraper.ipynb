# %% [markdown]
# # Tanzania Financial News Scraper
# ### DS & AI Year I: Data Collection Notebook
#
# This notebook collects financial news headlines from major Tanzanian news outlets
# for the period **2022 – 2024**. The collected dataset will be used for:
#
# - Sentiment analysis of financial news
# - Correlation analysis with TZS/USD exchange rates and inflation data
#
# **Target outlets:**
# - Daily News Tanzania (`dailynews.co.tz`)
# - The Citizen Tanzania (`thecitizen.co.tz`)
#
# **Authors:** *(add your names)*
# **Date:** *(add date)*

# %% [markdown]
# ---
# ## Section 1: Site Configuration
#
# This is the **only section you need to edit** when adding a new website.
#
# Each site is defined as a Python dictionary with five fields.
# The scraping functions in Section 4 read from these dictionaries automatically
# you never need to touch the functions.
#
# ### How to find the selectors for a new site
# 1. Open the site in Chrome/Firefox
# 2. Right-click an article headline → **Inspect**
# 3. Look at the HTML structure around the headline
# 4. Identify: what tag/class wraps the list of articles? What tag/class is the headline link inside?
#
# ### How to find the paginated URL pattern
# Navigate to page 2 of the category and look at the URL. Most WordPress sites follow:
# - `site.com/category/business/page/2/`  → pattern is `site.com/category/business/page/{}/`
# - `site.com/news/business?page=2`       → pattern is `site.com/news/business?page={}`
#
# The `{}` is where Python will insert the page number automatically.
#
# ---

# %% [markdown]
# ## Understanding Website Configuration in BeautifulSoup
#
# When scraping websites, it is common to create a **configuration dictionary** that stores information needed to locate and extract content.
#
# Instead of hardcoding selectors inside the scraping logic, we store them separately so the scraper becomes easier to maintain and reuse.
#
# The examples below use **Daily News** as a sample website, but these ideas apply to most websites.
#
# ### 1. `name`
#
# A simple label used to identify the website source.
#
# ```python
# "Daily News"
# ```
#
# Useful when scraping from multiple sources because it lets you track where collected data came from.
#
# ---
#
# ### 2. `base_url`
#
# Stores the page URL structure.
#
# ```python
# "https://dailynews.co.tz/category/business/page/{}/"
# ```
#
# The `{}` acts as a placeholder for page numbers.
#
# Examples:
#
# * `page/1`
# * `page/2`
# * `page/3`
#
# This allows the scraper to automatically move from one page to another while collecting data.
#
# ---
#
# ### 3. `article_container`
#
# CSS selector:
#
# ```python
# #masonry-grid
# ```
#
# `#` means select an element by **ID**.
#
# Looks for:
#
# ```html
# <div id="masonry-grid">
# ```
#
# The scraper first enters this section of the page so it focuses only on the area containing articles instead of searching the entire website.
#
# ---
#
# ### 4. `article_link_sel`
#
# CSS selector:
#
# ```python
# h2.entry-title a
# ```
#
# Breakdown:
#
# * `h2` → select `<h2>` tags
# * `.entry-title` → only those with class `entry-title`
# * `a` → links inside them
#
# The scraper uses this path to locate clickable article headlines and collect their titles and links.
#
# ---
#
# ### 5. `fallback_link_sel`
#
# Backup selector:
#
# ```python
# h2 a, h3 a
# ```
#
# The comma means **OR**.
#
# Looks for links inside:
#
# * `<h2>`
# * `<h3>`
#
# This acts as a backup option so the scraper can still find article links if the main page structure changes.
#
# ---
#
# ### 6. `date_sel`
#
# CSS selector:
#
# ```python
# span.date
# ```
#
# Targets:
#
# ```html
# <span class="date">
# ```
#
# The scraper looks for date elements and extracts the text inside them so publication dates can be saved.
#
# ---
#
# ### 7. `category_filter`
#
# Example:
#
# ```python
# None
# ```
#
# This means no filtering is applied.
#
# Since the example page already contains business articles, the scraper collects everything without needing extra filtering rules.
#
# ---
#
# ### 8. `base_domain`
#
# Example:
#
# ```python
# ''
# ```
#
# Used when websites provide **relative URLs**.
#
# Example:
#
# ```html
# <a href="/article/123">
# ```
#
# This helps convert incomplete links into full website URLs so they can be opened correctly.
#
# ---
#
# ### Why This Matters
#
# Think of this dictionary as a map for your scraper. It tells the program where to look and what to collect from a website, making the code easier to update and reuse.

# %%
# SITE CONFIGURATIONS — edit here to add new sites

DAILY_NEWS = {
    'name'             : 'Daily News',
    'base_url'         : 'https://dailynews.co.tz/category/business/page/{}/',
    'article_container': '#masonry-grid',
    'article_link_sel' : 'h2.entry-title a',
    'fallback_link_sel': 'h2 a, h3 a',
    'date_sel'         : 'span.date',          # <span class="date meta-item tie-icon">
    'category_filter'  : [],                 # no filtering needed, all posts are business
    'base_domain'      : '',                   # links are already absolute
}

THE_CITIZEN = {
    'name'             : 'The Citizen',
    'base_url'         : 'https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum={}&query=business&sortByDate=true',
    'article_container': None,
    'article_link_sel' : 'a.teaser-image-left',
    'fallback_link_sel': 'h3 a',
    'date_sel'         : 'span.date',          # same class, different content
    'category_filter'  : ['business','national'],           # skip OpEd and etc.
    'base_domain'      : 'https://www.thecitizen.co.tz',  # links are relative
}

# ── To add a new site, copy the template below and fill in the values ──
# NEW_SITE = {
#     'name'              : 'Site Name',
#     'base_url'          : 'https://example.com/category/page/{}/',
#     'article_container' : '#container-id or .container-class',
#     'article_link_sel'  : 'h2.entry-title a',
#     'fallback_link_sel' : 'h2 a, h3 a',
# }

print("✓ Site configs loaded")
print(f"  → {DAILY_NEWS['name']}: {DAILY_NEWS['base_url']}")
print(f"  → {THE_CITIZEN['name']}: {THE_CITIZEN['base_url']}")
# Out:
# ✓ Site configs loaded
#   → Daily News: https://dailynews.co.tz/category/business/page/{}/
#   → The Citizen: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum={}&query=business&sortByDate=true

# %% [markdown]
# ---
# ## Section 2: Core Scraping Functions
#
# These functions do all the heavy lifting. You should **never need to edit these**
# unless you want to change the scraping behaviour globally.
#
# | Function | What it does |
# |----------|-------------|
# | `scrape_article(url, source)` | Downloads one article page and extracts headline + date |
# | `get_article_urls(page_html, config)` | Extracts all article links from one listing page |
# | `scrape_site(config, start_page, end_page, output_file)` | Main loop — scrapes all pages and saves to CSV |
# | `append_to_csv(records, filename)` | Saves records without overwriting existing data |
#
# > 🔧 **Functions will be defined here in the next step.**

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os
import time
from datetime import datetime


# ══════════════════════════════════════════════════════
# FUNCTION 1: Parse date string to YYYY-MM-DD
# ══════════════════════════════════════════════════════

def parse_date(raw_date):
    """
    Converts a human-readable date string to YYYY-MM-DD format.

    Handles the format both Daily News and The Citizen use: "Aug 21, 2023"
    If parsing fails (e.g. relative dates like "Yesterday", "6 days ago"),
    the raw string is returned as-is so no data is lost.

    Args:
        raw_date : raw date string from the listing page

    Returns:
        "YYYY-MM-DD" string if parsing succeeds, otherwise the original string.
    """
    if not raw_date:
        return 'unknown'

    # Clean off anything after a dash e.g. "Aug 21, 2023 - 3 min read"
    cleaned = raw_date.split('-')[0].strip()

    try:
        return datetime.strptime(cleaned, "%B %d, %Y").strftime("%Y-%m-%d")  # "March 14, 2026"
    except ValueError:
        pass

    try:
        return datetime.strptime(cleaned, "%b %d, %Y").strftime("%Y-%m-%d")  # "Aug 21, 2023"
    except ValueError:
        pass

    # Couldn't parse — return raw string (handles relative dates gracefully)
    return cleaned


# ══════════════════════════════════════════════════════
# FUNCTION 2: Extract article links, headlines and dates
#             from one listing page
# ══════════════════════════════════════════════════════

def get_article_urls(page_html, config):
    """
    Extracts article headlines, links, and dates from one listing page.
    No article pages are opened — everything comes from the listing page only.

    Strategy:
    - Tries article_container first to narrow search scope
    - Falls back to full page search if container not found
    - Filters by category if config['category_filter'] is set (The Citizen)
    - Grabs headline from the link text directly
    - Grabs date from config['date_sel'] near each card

    Args:
        page_html : raw HTML string of the listing page
        config    : site config dict (DAILY_NEWS or THE_CITIZEN)

    Returns:
        List of dicts with keys: 'headline', 'url', 'date'
    """
    soup = BeautifulSoup(page_html, 'html.parser')
    results = []

    # ── Step 1: Find search scope ──
    container = None
    if config['article_container']:
        container = soup.select_one(config['article_container'])

    if container:
        search_scope = container
        selector = config['article_link_sel']
    else:
        if config['article_container']:
            # Was defined but not found on this page
            print(f"    ⚠ Container '{config['article_container']}' not found — using fallback")
            selector = config['fallback_link_sel']
        else:
            # Intentionally None (The Citizen) — use article_link_sel directly
            selector = config['article_link_sel']
        search_scope = soup

    # ── Step 2: Find all article cards ──
    cards = search_scope.select(selector)

    if not cards:
        print(f"    ⚠ No articles found with selector '{selector}'")
        return results

    # ── Step 3: Loop through each card ──
    for card in cards:

        # 3a: Category filtering (The Citizen only)
        if config['category_filter']:
            category_tag = card.select_one('span.article-topic')
            if not category_tag:
                continue
            if category_tag.get_text(strip=True).lower() not in config['category_filter']:
                continue

        # 3b: Get URL
        if card.name == 'a':
            relative_url = card.get('href', '').strip()
        else:
            inner_link = card.find('a')
            relative_url = inner_link.get('href', '').strip() if inner_link else ''

        if not relative_url:
            continue

        full_url = config['base_domain'] + relative_url

        # 3c: Get headline from link text — no article visit needed
        headline = card.get_text(strip=True)

        # For Daily News the <a> tag wraps only the headline text
        # For The Citizen the <a> wraps the whole card so we target the h3
        if config['name'] == 'The Citizen':
            h3 = card.select_one('h3.title-small')
            headline = h3.get_text(strip=True) if h3 else headline

        if not headline:
            continue

        # 3d: Get date from nearest parent card wrapper
        date = 'unknown'
        parent = card.find_parent(['article', 'li', 'div'])
        if parent:
            date_tag = parent.select_one(config['date_sel'])
            if date_tag:
                raw_date = date_tag.get_text(strip=True)
                date = parse_date(raw_date)

        results.append({
            'headline' : headline,
            'url'      : full_url,
            'date'     : date,
        })

    return results


# ══════════════════════════════════════════════════════
# FUNCTION 3: Save records to CSV
# ══════════════════════════════════════════════════════

def append_to_csv(records, filename):
    """
    Appends a list of article records to a CSV file.

    Creates the file with a header row on first write.
    On subsequent writes, appends without repeating the header.
    Safe to call after every page or checkpoint — no data is ever overwritten.

    Args:
        records  : list of dicts with keys: date, headline, url, source, scraped_on
        filename : path to the output CSV file
    """
    if not records:
        return

    file_exists = os.path.isfile(filename)

    with open(filename, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['date', 'headline', 'url', 'source', 'scraped_on'])
        if not file_exists:
            writer.writeheader()
        writer.writerows(records)


# ══════════════════════════════════════════════════════
# FUNCTION 4: Main scraping loop
# ══════════════════════════════════════════════════════

def scrape_site(config, start_page, end_page, output_file):
    """
    Main loop. Scrapes every listing page from start_page to end_page,
    extracts headlines, dates, and URLs entirely from listing pages,
    and saves to CSV with checkpoints every 20 pages.

    Resumable: increase start_page to last successful page after a crash.
    Checkpoint saves happen every 20 pages so you never lose more than
    20 pages of work.

    Args:
        config      : site config dict (DAILY_NEWS or THE_CITIZEN)
        start_page  : first page number to scrape
        end_page    : last page number to scrape (inclusive)
        output_file : filename for the output CSV
    """
    print(f"\n{'='*55}")
    print(f"  Starting scrape : {config['name']}")
    print(f"  Pages           : {start_page} → {end_page}")
    print(f"  Output          : {output_file}")
    print(f"{'='*55}\n")

    # Today's date stamped on every record so you know when this run happened
    scraped_on = datetime.today().strftime("%Y-%m-%d")

    total_saved  = 0
    batch_records = []   # accumulates records until checkpoint

    for page_num in range(start_page, end_page + 1):

        page_url = config['base_url'].format(page_num)
        print(f"[Page {page_num}] Fetching: {page_url}")

        # ── Fetch listing page ──
        try:
            response = requests.get(page_url, timeout=10, headers={
                'User-Agent': 'Mozilla/5.0 (compatible; research-scraper/1.0)'
            })

            # 404 means we've gone past the last page — stop cleanly
            if response.status_code == 404:
                print(f"  404 reached at page {page_num} — end of archive, stopping\n")
                break

            response.raise_for_status()

        except requests.RequestException as e:
            print(f"  ⚠ WARNING: Could not load page {page_num} — skipping")
            print(f"    Reason: {e}\n")
            continue

        # ── Extract articles from listing page ──
        articles = get_article_urls(response.text, config)

        if not articles:
            print(f"  ⚠ WARNING: No articles found on page {page_num} — skipping\n")
            continue

        # ── Build records and add metadata ──
        for article in articles:
            batch_records.append({
                'date'      : article['date'],
                'headline'  : article['headline'],
                'url'       : article['url'],
                'source'    : config['name'],
                'scraped_on': scraped_on,
            })

        total_saved += len(articles)
        print(f"  ✓ {len(articles)} articles collected (total so far: {total_saved})")

        # ── Checkpoint save every 20 pages ──
        if page_num % 20 == 0:
            append_to_csv(batch_records, output_file)
            batch_records = []   # clear batch after saving
            print(f"\tCheckpoint saved at page {page_num} — {total_saved} records in {output_file}")

        time.sleep(1)   # be polite between listing page requests

    # ── Save any remaining records that didn't hit a checkpoint ──
    if batch_records:
        append_to_csv(batch_records, output_file)
        print(f"\n\tFinal save: {len(batch_records)} remaining records written\n")

    print(f"\n{'='*55}")
    print(f"  ✓ Scrape complete!")
    print(f"  Total headlines saved : {total_saved}")
    print(f"  File                  : {output_file}")
    print(f"{'='*55}\n")

# %% [markdown]
# ---
# ## Section 3: Run the Scraper
#
# This is where you actually collect data. Three steps:
#
# 1. Choose your site config from Section 3
# 2. Set your page range (check the site manually to find which pages cover 2022–2024)
# 3. Set your output filename and run
#
# To **resume** from where you left off after a crash, just change `start_page`
# to the last page that successfully saved. The append function ensures no data is lost
# and no duplicate headers are written.

# %%
# ══════════════════════════════════════════════════════
# RUN CONFIGURATION — change these values as needed
# ══════════════════════════════════════════════════════


# citizen pages btn 424 to 841
# daily news btn 287 to 683

scrape_site(THE_CITIZEN,424,841,"final_news_scrape.csv")
# Out:
# =======================================================
#   Starting scrape : The Citizen
#   Pages           : 424 → 841
#   Output          : final_news_scrape.csv
# =======================================================
#
# [Page 424] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=424&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 4)
# [Page 425] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=425&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 10)
# [Page 426] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=426&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 17)
# [Page 427] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=427&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 19)
# [Page 428] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=428&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 20)
# [Page 429] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=429&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 25)
# [Page 430] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=430&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 29)
# [Page 431] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=431&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 33)
# [Page 432] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=432&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 35)
# [Page 433] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=433&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 433 — skipping
#
# [Page 434] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=434&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 41)
# [Page 435] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=435&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 44)
# [Page 436] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=436&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 47)
# [Page 437] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=437&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 50)
# [Page 438] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=438&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 56)
# [Page 439] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=439&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 58)
# [Page 440] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=440&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 59)
# 	Checkpoint saved at page 440 — 59 records in final_news_scrape.csv
# [Page 441] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=441&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 61)
# [Page 442] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=442&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 64)
# [Page 443] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=443&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 71)
# [Page 444] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=444&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 72)
# [Page 445] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=445&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 77)
# [Page 446] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=446&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 79)
# [Page 447] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=447&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 86)
# [Page 448] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=448&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 89)
# [Page 449] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=449&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 91)
# [Page 450] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=450&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 98)
# [Page 451] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=451&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 100)
# [Page 452] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=452&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 102)
# [Page 453] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=453&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 105)
# [Page 454] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=454&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 108)
# [Page 455] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=455&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 111)
# [Page 456] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=456&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 113)
# [Page 457] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=457&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 117)
# [Page 458] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=458&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 118)
# [Page 459] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=459&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 119)
# [Page 460] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=460&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 123)
# 	Checkpoint saved at page 460 — 123 records in final_news_scrape.csv
# [Page 461] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=461&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 125)
# [Page 462] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=462&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 130)
# [Page 463] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=463&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 133)
# [Page 464] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=464&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 136)
# [Page 465] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=465&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 141)
# [Page 466] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=466&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 144)
# [Page 467] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=467&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 147)
# [Page 468] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=468&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 149)
# [Page 469] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=469&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 153)
# [Page 470] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=470&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 157)
# [Page 471] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=471&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 161)
# [Page 472] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=472&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 166)
# [Page 473] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=473&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 168)
# [Page 474] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=474&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 172)
# [Page 475] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=475&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 174)
# [Page 476] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=476&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 177)
# [Page 477] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=477&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 182)
# [Page 478] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=478&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 185)
# [Page 479] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=479&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 186)
# [Page 480] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=480&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 188)
# 	Checkpoint saved at page 480 — 188 records in final_news_scrape.csv
# [Page 481] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=481&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 190)
# [Page 482] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=482&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 194)
# [Page 483] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=483&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 197)
# [Page 484] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=484&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 201)
# [Page 485] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=485&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 207)
# [Page 486] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=486&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 212)
# [Page 487] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=487&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 215)
# [Page 488] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=488&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 217)
# [Page 489] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=489&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 218)
# [Page 490] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=490&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 222)
# [Page 491] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=491&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 224)
# [Page 492] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=492&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 225)
# [Page 493] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=493&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 226)
# [Page 494] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=494&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 229)
# [Page 495] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=495&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 231)
# [Page 496] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=496&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 238)
# [Page 497] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=497&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 243)
# [Page 498] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=498&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 248)
# [Page 499] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=499&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 252)
# [Page 500] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=500&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 258)
# 	Checkpoint saved at page 500 — 258 records in final_news_scrape.csv
# [Page 501] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=501&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 260)
# [Page 502] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=502&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 262)
# [Page 503] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=503&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 267)
# [Page 504] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=504&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 270)
# [Page 505] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=505&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 272)
# [Page 506] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=506&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 274)
# [Page 507] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=507&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 277)
# [Page 508] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=508&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 279)
# [Page 509] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=509&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 281)
# [Page 510] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=510&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 283)
# [Page 511] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=511&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 285)
# [Page 512] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=512&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 512 — skipping
#
# [Page 513] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=513&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 286)
# [Page 514] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=514&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 291)
# [Page 515] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=515&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 292)
# [Page 516] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=516&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 297)
# [Page 517] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=517&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 300)
# [Page 518] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=518&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 301)
# [Page 519] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=519&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 302)
# [Page 520] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=520&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 304)
# 	Checkpoint saved at page 520 — 304 records in final_news_scrape.csv
# [Page 521] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=521&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 305)
# [Page 522] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=522&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 307)
# [Page 523] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=523&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 309)
# [Page 524] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=524&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 314)
# [Page 525] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=525&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 318)
# [Page 526] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=526&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 320)
# [Page 527] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=527&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 321)
# [Page 528] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=528&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 323)
# [Page 529] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=529&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 325)
# [Page 530] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=530&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 328)
# [Page 531] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=531&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 330)
# [Page 532] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=532&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 532 — skipping
#
# [Page 533] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=533&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 335)
# [Page 534] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=534&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 341)
# [Page 535] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=535&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 343)
# [Page 536] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=536&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 346)
# [Page 537] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=537&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 352)
# [Page 538] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=538&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 356)
# [Page 539] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=539&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 361)
# [Page 540] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=540&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 362)
# 	Checkpoint saved at page 540 — 362 records in final_news_scrape.csv
# [Page 541] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=541&query=business&sortByDate=true
#     ⚠ No articles found with selector 'a.teaser-image-left'
#   ⚠ WARNING: No articles found on page 541 — skipping
#
# [Page 542] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=542&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 365)
# [Page 543] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=543&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 543 — skipping
#
# [Page 544] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=544&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 367)
# [Page 545] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=545&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 368)
# [Page 546] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=546&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 370)
# [Page 547] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=547&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 373)
# [Page 548] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=548&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 375)
# [Page 549] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=549&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 376)
# [Page 550] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=550&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 381)
# [Page 551] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=551&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 387)
# [Page 552] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=552&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 393)
# [Page 553] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=553&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 400)
# [Page 554] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=554&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 408)
# [Page 555] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=555&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 415)
# [Page 556] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=556&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 417)
# [Page 557] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=557&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 422)
# [Page 558] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=558&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 423)
# [Page 559] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=559&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 559 — skipping
#
# [Page 560] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=560&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 560 — skipping
#
# [Page 561] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=561&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 425)
# [Page 562] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=562&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 429)
# [Page 563] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=563&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 431)
# [Page 564] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=564&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 432)
# [Page 565] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=565&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 433)
# [Page 566] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=566&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 434)
# [Page 567] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=567&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 567 — skipping
#
# [Page 568] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=568&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 568 — skipping
#
# [Page 569] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=569&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 439)
# [Page 570] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=570&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 441)
# [Page 571] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=571&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 442)
# [Page 572] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=572&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 444)
# [Page 573] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=573&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 449)
# [Page 574] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=574&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 451)
# [Page 575] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=575&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 454)
# [Page 576] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=576&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 458)
# [Page 577] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=577&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 577 — skipping
#
# [Page 578] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=578&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 460)
# [Page 579] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=579&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 465)
# [Page 580] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=580&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 467)
# 	Checkpoint saved at page 580 — 467 records in final_news_scrape.csv
# [Page 581] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=581&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 469)
# [Page 582] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=582&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 470)
# [Page 583] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=583&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 472)
# [Page 584] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=584&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 474)
# [Page 585] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=585&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 475)
# [Page 586] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=586&query=business&sortByDate=true
#   ⚠ WARNING: No articles found on page 586 — skipping
#
# [Page 587] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=587&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 476)
# [Page 588] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=588&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 479)
# [Page 589] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=589&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 483)
# [Page 590] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=590&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 484)
# [Page 591] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=591&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 490)
# [Page 592] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=592&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 493)
# [Page 593] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=593&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 496)
# [Page 594] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=594&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 497)
# [Page 595] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=595&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 500)
# [Page 596] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=596&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 502)
# [Page 597] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=597&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 505)
# [Page 598] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=598&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 507)
# [Page 599] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=599&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 508)
# [Page 600] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=600&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 516)
# 	Checkpoint saved at page 600 — 516 records in final_news_scrape.csv
# [Page 601] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=601&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 521)
# [Page 602] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=602&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 524)
# [Page 603] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=603&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 526)
# [Page 604] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=604&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 531)
# [Page 605] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=605&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 537)
# [Page 606] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=606&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 540)
# [Page 607] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=607&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 542)
# [Page 608] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=608&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 547)
# [Page 609] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=609&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 550)
# [Page 610] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=610&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 554)
# [Page 611] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=611&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 555)
# [Page 612] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=612&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 558)
# [Page 613] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=613&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 562)
# [Page 614] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=614&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 566)
# [Page 615] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=615&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 569)
# [Page 616] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=616&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 571)
# [Page 617] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=617&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 576)
# [Page 618] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=618&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 579)
# [Page 619] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=619&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 583)
# [Page 620] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=620&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 587)
# 	Checkpoint saved at page 620 — 587 records in final_news_scrape.csv
# [Page 621] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=621&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 590)
# [Page 622] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=622&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 594)
# [Page 623] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=623&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 599)
# [Page 624] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=624&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 604)
# [Page 625] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=625&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 608)
# [Page 626] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=626&query=business&sortByDate=true
#   ⚠ WARNING: Could not load page 626 — skipping
#     Reason: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# [Page 627] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=627&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 610)
# [Page 628] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=628&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 612)
# [Page 629] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=629&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 617)
# [Page 630] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=630&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 620)
# [Page 631] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=631&query=business&sortByDate=true
#   ✓ 1 articles collected (total so far: 621)
# [Page 632] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=632&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 626)
# [Page 633] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=633&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 631)
# [Page 634] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=634&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 636)
# [Page 635] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=635&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 641)
# [Page 636] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=636&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 646)
# [Page 637] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=637&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 652)
# [Page 638] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=638&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 654)
# [Page 639] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=639&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 657)
# [Page 640] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=640&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 661)
# 	Checkpoint saved at page 640 — 661 records in final_news_scrape.csv
# [Page 641] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=641&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 665)
# [Page 642] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=642&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 671)
# [Page 643] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=643&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 676)
# [Page 644] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=644&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 684)
# [Page 645] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=645&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 692)
# [Page 646] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=646&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 698)
# [Page 647] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=647&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 705)
# [Page 648] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=648&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 709)
# [Page 649] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=649&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 716)
# [Page 650] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=650&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 721)
# [Page 651] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=651&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 723)
# [Page 652] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=652&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 730)
# [Page 653] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=653&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 734)
# [Page 654] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=654&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 736)
# [Page 655] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=655&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 740)
# [Page 656] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=656&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 745)
# [Page 657] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=657&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 750)
# [Page 658] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=658&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 752)
# [Page 659] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=659&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 758)
# [Page 660] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=660&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 764)
# 	Checkpoint saved at page 660 — 764 records in final_news_scrape.csv
# [Page 661] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=661&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 770)
# [Page 662] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=662&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 778)
# [Page 663] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=663&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 781)
# [Page 664] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=664&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 783)
# [Page 665] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=665&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 789)
# [Page 666] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=666&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 795)
# [Page 667] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=667&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 800)
# [Page 668] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=668&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 802)
# [Page 669] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=669&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 805)
# [Page 670] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=670&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 813)
# [Page 671] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=671&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 819)
# [Page 672] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=672&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 824)
# [Page 673] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=673&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 829)
# [Page 674] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=674&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 834)
# [Page 675] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=675&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 838)
# [Page 676] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=676&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 844)
# [Page 677] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=677&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 846)
# [Page 678] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=678&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 851)
# [Page 679] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=679&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 855)
# [Page 680] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=680&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 859)
# 	Checkpoint saved at page 680 — 859 records in final_news_scrape.csv
# [Page 681] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=681&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 867)
# [Page 682] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=682&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 871)
# [Page 683] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=683&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 875)
# [Page 684] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=684&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 880)
# [Page 685] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=685&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 884)
# [Page 686] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=686&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 891)
# [Page 687] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=687&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 894)
# [Page 688] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=688&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 901)
# [Page 689] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=689&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 906)
# [Page 690] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=690&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 913)
# [Page 691] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=691&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 917)
# [Page 692] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=692&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 922)
# [Page 693] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=693&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 929)
# [Page 694] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=694&query=business&sortByDate=true
#   ✓ 9 articles collected (total so far: 938)
# [Page 695] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=695&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 942)
# [Page 696] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=696&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 946)
# [Page 697] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=697&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 950)
# ...
# [Page 752] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=752&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1241)
# [Page 753] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=753&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1249)
# [Page 754] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=754&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1257)
# [Page 755] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=755&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1261)
# [Page 756] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=756&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1265)
# [Page 757] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=757&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1271)
# [Page 758] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=758&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1274)
# [Page 759] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=759&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1282)
# [Page 760] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=760&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1290)
# 	Checkpoint saved at page 760 — 1290 records in final_news_scrape.csv
# [Page 761] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=761&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1296)
# [Page 762] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=762&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1303)
# [Page 763] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=763&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1309)
# [Page 764] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=764&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1314)
# [Page 765] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=765&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1321)
# [Page 766] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=766&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1326)
# [Page 767] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=767&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1332)
# [Page 768] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=768&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1338)
# [Page 769] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=769&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1344)
# [Page 770] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=770&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1350)
# [Page 771] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=771&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1356)
# [Page 772] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=772&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1363)
# [Page 773] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=773&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1368)
# [Page 774] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=774&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1374)
# [Page 775] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=775&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1379)
# [Page 776] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=776&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1385)
# [Page 777] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=777&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1392)
# [Page 778] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=778&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1398)
# [Page 779] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=779&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1406)
# [Page 780] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=780&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1412)
# 	Checkpoint saved at page 780 — 1412 records in final_news_scrape.csv
# [Page 781] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=781&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1419)
# [Page 782] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=782&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1423)
# [Page 783] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=783&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1429)
# [Page 784] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=784&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1437)
# [Page 785] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=785&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1442)
# [Page 786] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=786&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1448)
# [Page 787] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=787&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1453)
# [Page 788] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=788&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1458)
# [Page 789] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=789&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1463)
# [Page 790] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=790&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1469)
# [Page 791] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=791&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1477)
# [Page 792] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=792&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1485)
# [Page 793] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=793&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1491)
# [Page 794] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=794&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1498)
# [Page 795] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=795&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1501)
# [Page 796] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=796&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1507)
# [Page 797] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=797&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1510)
# [Page 798] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=798&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1514)
# [Page 799] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=799&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1519)
# [Page 800] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=800&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1522)
# 	Checkpoint saved at page 800 — 1522 records in final_news_scrape.csv
# [Page 801] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=801&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1528)
# [Page 802] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=802&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1535)
# [Page 803] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=803&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1540)
# [Page 804] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=804&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1545)
# [Page 805] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=805&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1549)
# [Page 806] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=806&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1555)
# [Page 807] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=807&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1558)
# [Page 808] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=808&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1565)
# [Page 809] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=809&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1569)
# [Page 810] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=810&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1573)
# [Page 811] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=811&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1577)
# [Page 812] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=812&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1582)
# [Page 813] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=813&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1587)
# [Page 814] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=814&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1591)
# [Page 815] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=815&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1594)
# [Page 816] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=816&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1600)
# [Page 817] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=817&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1604)
# [Page 818] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=818&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1609)
# [Page 819] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=819&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1615)
# [Page 820] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=820&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1620)
# 	Checkpoint saved at page 820 — 1620 records in final_news_scrape.csv
# [Page 821] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=821&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1627)
# [Page 822] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=822&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1632)
# [Page 823] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=823&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1635)
# [Page 824] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=824&query=business&sortByDate=true
#   ✓ 2 articles collected (total so far: 1637)
# [Page 825] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=825&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1644)
# [Page 826] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=826&query=business&sortByDate=true
#   ✓ 4 articles collected (total so far: 1648)
# [Page 827] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=827&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1651)
# [Page 828] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=828&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1659)
# [Page 829] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=829&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1666)
# [Page 830] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=830&query=business&sortByDate=true
#   ✓ 8 articles collected (total so far: 1674)
# [Page 831] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=831&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1681)
# [Page 832] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=832&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1687)
# [Page 833] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=833&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1693)
# [Page 834] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=834&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1700)
# [Page 835] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=835&query=business&sortByDate=true
#   ✓ 3 articles collected (total so far: 1703)
# [Page 836] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=836&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1709)
# [Page 837] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=837&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1716)
# [Page 838] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=838&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1723)
# [Page 839] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=839&query=business&sortByDate=true
#   ✓ 6 articles collected (total so far: 1729)
# [Page 840] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=840&query=business&sortByDate=true
#   ✓ 7 articles collected (total so far: 1736)
# 	Checkpoint saved at page 840 — 1736 records in final_news_scrape.csv
# [Page 841] Fetching: https://www.thecitizen.co.tz/service/search/tanzania/2718734?pageNum=841&query=business&sortByDate=true
#   ✓ 5 articles collected (total so far: 1741)
#
# 	Final save: 5 remaining records written
#
#
# =======================================================
#   ✓ Scrape complete!
#   Total headlines saved : 1741
#   File                  : final_news_scrape.csv
# =======================================================

# %%
# citizen pages btn 424 to 841
# daily news btn 287 to 683

scrape_site(DAILY_NEWS,287,683,"final_news_scrape.csv")
# Out:
# =======================================================
#   Starting scrape : Daily News
#   Pages           : 287 → 683
#   Output          : final_news_scrape.csv
# =======================================================
#
# [Page 287] Fetching: https://dailynews.co.tz/category/business/page/287/
#   ✓ 10 articles collected (total so far: 10)
# [Page 288] Fetching: https://dailynews.co.tz/category/business/page/288/
#   ✓ 10 articles collected (total so far: 20)
# [Page 289] Fetching: https://dailynews.co.tz/category/business/page/289/
#   ✓ 10 articles collected (total so far: 30)
# [Page 290] Fetching: https://dailynews.co.tz/category/business/page/290/
#   ✓ 10 articles collected (total so far: 40)
# [Page 291] Fetching: https://dailynews.co.tz/category/business/page/291/
#   ✓ 10 articles collected (total so far: 50)
# [Page 292] Fetching: https://dailynews.co.tz/category/business/page/292/
#   ✓ 10 articles collected (total so far: 60)
# [Page 293] Fetching: https://dailynews.co.tz/category/business/page/293/
#   ✓ 10 articles collected (total so far: 70)
# [Page 294] Fetching: https://dailynews.co.tz/category/business/page/294/
#   ✓ 10 articles collected (total so far: 80)
# [Page 295] Fetching: https://dailynews.co.tz/category/business/page/295/
#   ✓ 10 articles collected (total so far: 90)
# [Page 296] Fetching: https://dailynews.co.tz/category/business/page/296/
#   ✓ 10 articles collected (total so far: 100)
# [Page 297] Fetching: https://dailynews.co.tz/category/business/page/297/
#   ✓ 10 articles collected (total so far: 110)
# [Page 298] Fetching: https://dailynews.co.tz/category/business/page/298/
#   ✓ 10 articles collected (total so far: 120)
# [Page 299] Fetching: https://dailynews.co.tz/category/business/page/299/
#   ✓ 10 articles collected (total so far: 130)
# [Page 300] Fetching: https://dailynews.co.tz/category/business/page/300/
#   ✓ 10 articles collected (total so far: 140)
# 	Checkpoint saved at page 300 — 140 records in final_news_scrape.csv
# [Page 301] Fetching: https://dailynews.co.tz/category/business/page/301/
#   ✓ 10 articles collected (total so far: 150)
# [Page 302] Fetching: https://dailynews.co.tz/category/business/page/302/
#   ✓ 10 articles collected (total so far: 160)
# [Page 303] Fetching: https://dailynews.co.tz/category/business/page/303/
#   ✓ 10 articles collected (total so far: 170)
# [Page 304] Fetching: https://dailynews.co.tz/category/business/page/304/
#   ✓ 10 articles collected (total so far: 180)
# [Page 305] Fetching: https://dailynews.co.tz/category/business/page/305/
#   ✓ 10 articles collected (total so far: 190)
# [Page 306] Fetching: https://dailynews.co.tz/category/business/page/306/
#   ✓ 10 articles collected (total so far: 200)
# [Page 307] Fetching: https://dailynews.co.tz/category/business/page/307/
#   ✓ 10 articles collected (total so far: 210)
# [Page 308] Fetching: https://dailynews.co.tz/category/business/page/308/
#   ✓ 10 articles collected (total so far: 220)
# [Page 309] Fetching: https://dailynews.co.tz/category/business/page/309/
#   ✓ 10 articles collected (total so far: 230)
# [Page 310] Fetching: https://dailynews.co.tz/category/business/page/310/
#   ✓ 10 articles collected (total so far: 240)
# [Page 311] Fetching: https://dailynews.co.tz/category/business/page/311/
#   ✓ 10 articles collected (total so far: 250)
# [Page 312] Fetching: https://dailynews.co.tz/category/business/page/312/
#   ✓ 10 articles collected (total so far: 260)
# [Page 313] Fetching: https://dailynews.co.tz/category/business/page/313/
#   ✓ 10 articles collected (total so far: 270)
# [Page 314] Fetching: https://dailynews.co.tz/category/business/page/314/
#   ✓ 10 articles collected (total so far: 280)
# [Page 315] Fetching: https://dailynews.co.tz/category/business/page/315/
#   ✓ 10 articles collected (total so far: 290)
# [Page 316] Fetching: https://dailynews.co.tz/category/business/page/316/
#   ✓ 10 articles collected (total so far: 300)
# [Page 317] Fetching: https://dailynews.co.tz/category/business/page/317/
#   ✓ 10 articles collected (total so far: 310)
# [Page 318] Fetching: https://dailynews.co.tz/category/business/page/318/
#   ✓ 10 articles collected (total so far: 320)
# [Page 319] Fetching: https://dailynews.co.tz/category/business/page/319/
#   ✓ 10 articles collected (total so far: 330)
# [Page 320] Fetching: https://dailynews.co.tz/category/business/page/320/
#   ✓ 10 articles collected (total so far: 340)
# 	Checkpoint saved at page 320 — 340 records in final_news_scrape.csv
# [Page 321] Fetching: https://dailynews.co.tz/category/business/page/321/
#   ✓ 10 articles collected (total so far: 350)
# [Page 322] Fetching: https://dailynews.co.tz/category/business/page/322/
#   ✓ 10 articles collected (total so far: 360)
# [Page 323] Fetching: https://dailynews.co.tz/category/business/page/323/
#   ✓ 10 articles collected (total so far: 370)
# [Page 324] Fetching: https://dailynews.co.tz/category/business/page/324/
#   ✓ 10 articles collected (total so far: 380)
# [Page 325] Fetching: https://dailynews.co.tz/category/business/page/325/
#   ✓ 10 articles collected (total so far: 390)
# [Page 326] Fetching: https://dailynews.co.tz/category/business/page/326/
#   ✓ 10 articles collected (total so far: 400)
# [Page 327] Fetching: https://dailynews.co.tz/category/business/page/327/
#   ✓ 10 articles collected (total so far: 410)
# [Page 328] Fetching: https://dailynews.co.tz/category/business/page/328/
#   ✓ 10 articles collected (total so far: 420)
# [Page 329] Fetching: https://dailynews.co.tz/category/business/page/329/
#   ✓ 10 articles collected (total so far: 430)
# [Page 330] Fetching: https://dailynews.co.tz/category/business/page/330/
#   ✓ 10 articles collected (total so far: 440)
# [Page 331] Fetching: https://dailynews.co.tz/category/business/page/331/
#   ✓ 10 articles collected (total so far: 450)
# [Page 332] Fetching: https://dailynews.co.tz/category/business/page/332/
#   ✓ 10 articles collected (total so far: 460)
# [Page 333] Fetching: https://dailynews.co.tz/category/business/page/333/
#   ✓ 10 articles collected (total so far: 470)
# [Page 334] Fetching: https://dailynews.co.tz/category/business/page/334/
#   ✓ 10 articles collected (total so far: 480)
# [Page 335] Fetching: https://dailynews.co.tz/category/business/page/335/
#   ✓ 10 articles collected (total so far: 490)
# [Page 336] Fetching: https://dailynews.co.tz/category/business/page/336/
#   ✓ 10 articles collected (total so far: 500)
# [Page 337] Fetching: https://dailynews.co.tz/category/business/page/337/
#   ✓ 10 articles collected (total so far: 510)
# [Page 338] Fetching: https://dailynews.co.tz/category/business/page/338/
#   ✓ 10 articles collected (total so far: 520)
# [Page 339] Fetching: https://dailynews.co.tz/category/business/page/339/
#   ✓ 10 articles collected (total so far: 530)
# [Page 340] Fetching: https://dailynews.co.tz/category/business/page/340/
#   ✓ 10 articles collected (total so far: 540)
# 	Checkpoint saved at page 340 — 540 records in final_news_scrape.csv
# [Page 341] Fetching: https://dailynews.co.tz/category/business/page/341/
#   ✓ 10 articles collected (total so far: 550)
# [Page 342] Fetching: https://dailynews.co.tz/category/business/page/342/
#   ✓ 10 articles collected (total so far: 560)
# [Page 343] Fetching: https://dailynews.co.tz/category/business/page/343/
#   ✓ 10 articles collected (total so far: 570)
# [Page 344] Fetching: https://dailynews.co.tz/category/business/page/344/
#   ✓ 10 articles collected (total so far: 580)
# [Page 345] Fetching: https://dailynews.co.tz/category/business/page/345/
#   ✓ 10 articles collected (total so far: 590)
# [Page 346] Fetching: https://dailynews.co.tz/category/business/page/346/
#   ✓ 10 articles collected (total so far: 600)
# [Page 347] Fetching: https://dailynews.co.tz/category/business/page/347/
#   ✓ 10 articles collected (total so far: 610)
# [Page 348] Fetching: https://dailynews.co.tz/category/business/page/348/
#   ✓ 10 articles collected (total so far: 620)
# [Page 349] Fetching: https://dailynews.co.tz/category/business/page/349/
#   ✓ 10 articles collected (total so far: 630)
# [Page 350] Fetching: https://dailynews.co.tz/category/business/page/350/
#   ✓ 10 articles collected (total so far: 640)
# [Page 351] Fetching: https://dailynews.co.tz/category/business/page/351/
#   ✓ 10 articles collected (total so far: 650)
# [Page 352] Fetching: https://dailynews.co.tz/category/business/page/352/
#   ✓ 10 articles collected (total so far: 660)
# [Page 353] Fetching: https://dailynews.co.tz/category/business/page/353/
#   ✓ 10 articles collected (total so far: 670)
# [Page 354] Fetching: https://dailynews.co.tz/category/business/page/354/
#   ✓ 10 articles collected (total so far: 680)
# [Page 355] Fetching: https://dailynews.co.tz/category/business/page/355/
#   ✓ 10 articles collected (total so far: 690)
# [Page 356] Fetching: https://dailynews.co.tz/category/business/page/356/
#   ✓ 10 articles collected (total so far: 700)
# [Page 357] Fetching: https://dailynews.co.tz/category/business/page/357/
#   ✓ 10 articles collected (total so far: 710)
# [Page 358] Fetching: https://dailynews.co.tz/category/business/page/358/
#   ✓ 10 articles collected (total so far: 720)
# [Page 359] Fetching: https://dailynews.co.tz/category/business/page/359/
#   ✓ 10 articles collected (total so far: 730)
# [Page 360] Fetching: https://dailynews.co.tz/category/business/page/360/
#   ✓ 10 articles collected (total so far: 740)
# 	Checkpoint saved at page 360 — 740 records in final_news_scrape.csv
# [Page 361] Fetching: https://dailynews.co.tz/category/business/page/361/
#   ✓ 10 articles collected (total so far: 750)
# [Page 362] Fetching: https://dailynews.co.tz/category/business/page/362/
#   ✓ 10 articles collected (total so far: 760)
# [Page 363] Fetching: https://dailynews.co.tz/category/business/page/363/
#   ✓ 10 articles collected (total so far: 770)
# [Page 364] Fetching: https://dailynews.co.tz/category/business/page/364/
#   ✓ 10 articles collected (total so far: 780)
# [Page 365] Fetching: https://dailynews.co.tz/category/business/page/365/
#   ✓ 10 articles collected (total so far: 790)
# [Page 366] Fetching: https://dailynews.co.tz/category/business/page/366/
#   ✓ 10 articles collected (total so far: 800)
# [Page 367] Fetching: https://dailynews.co.tz/category/business/page/367/
#   ✓ 10 articles collected (total so far: 810)
# [Page 368] Fetching: https://dailynews.co.tz/category/business/page/368/
#   ✓ 10 articles collected (total so far: 820)
# [Page 369] Fetching: https://dailynews.co.tz/category/business/page/369/
#   ✓ 10 articles collected (total so far: 830)
# [Page 370] Fetching: https://dailynews.co.tz/category/business/page/370/
#   ✓ 10 articles collected (total so far: 840)
# [Page 371] Fetching: https://dailynews.co.tz/category/business/page/371/
#   ✓ 10 articles collected (total so far: 850)
# [Page 372] Fetching: https://dailynews.co.tz/category/business/page/372/
#   ✓ 10 articles collected (total so far: 860)
# [Page 373] Fetching: https://dailynews.co.tz/category/business/page/373/
#   ✓ 10 articles collected (total so far: 870)
# [Page 374] Fetching: https://dailynews.co.tz/category/business/page/374/
#   ✓ 10 articles collected (total so far: 880)
# [Page 375] Fetching: https://dailynews.co.tz/category/business/page/375/
#   ✓ 10 articles collected (total so far: 890)
# [Page 376] Fetching: https://dailynews.co.tz/category/business/page/376/
#   ✓ 10 articles collected (total so far: 900)
# [Page 377] Fetching: https://dailynews.co.tz/category/business/page/377/
#   ✓ 10 articles collected (total so far: 910)
# [Page 378] Fetching: https://dailynews.co.tz/category/business/page/378/
#   ✓ 10 articles collected (total so far: 920)
# [Page 379] Fetching: https://dailynews.co.tz/category/business/page/379/
#   ✓ 10 articles collected (total so far: 930)
# [Page 380] Fetching: https://dailynews.co.tz/category/business/page/380/
#   ✓ 10 articles collected (total so far: 940)
# 	Checkpoint saved at page 380 — 940 records in final_news_scrape.csv
# [Page 381] Fetching: https://dailynews.co.tz/category/business/page/381/
#   ✓ 10 articles collected (total so far: 950)
# [Page 382] Fetching: https://dailynews.co.tz/category/business/page/382/
#   ✓ 10 articles collected (total so far: 960)
# [Page 383] Fetching: https://dailynews.co.tz/category/business/page/383/
#   ✓ 10 articles collected (total so far: 970)
# [Page 384] Fetching: https://dailynews.co.tz/category/business/page/384/
#   ✓ 10 articles collected (total so far: 980)
# [Page 385] Fetching: https://dailynews.co.tz/category/business/page/385/
#   ✓ 10 articles collected (total so far: 990)
# [Page 386] Fetching: https://dailynews.co.tz/category/business/page/386/
#   ✓ 10 articles collected (total so far: 1000)
# [Page 387] Fetching: https://dailynews.co.tz/category/business/page/387/
#   ✓ 10 articles collected (total so far: 1010)
# [Page 388] Fetching: https://dailynews.co.tz/category/business/page/388/
#   ✓ 10 articles collected (total so far: 1020)
# [Page 389] Fetching: https://dailynews.co.tz/category/business/page/389/
#   ✓ 10 articles collected (total so far: 1030)
# [Page 390] Fetching: https://dailynews.co.tz/category/business/page/390/
#   ✓ 10 articles collected (total so far: 1040)
# [Page 391] Fetching: https://dailynews.co.tz/category/business/page/391/
#   ✓ 10 articles collected (total so far: 1050)
# [Page 392] Fetching: https://dailynews.co.tz/category/business/page/392/
#   ✓ 10 articles collected (total so far: 1060)
# [Page 393] Fetching: https://dailynews.co.tz/category/business/page/393/
#   ✓ 10 articles collected (total so far: 1070)
# [Page 394] Fetching: https://dailynews.co.tz/category/business/page/394/
#   ✓ 10 articles collected (total so far: 1080)
# [Page 395] Fetching: https://dailynews.co.tz/category/business/page/395/
#   ✓ 10 articles collected (total so far: 1090)
# [Page 396] Fetching: https://dailynews.co.tz/category/business/page/396/
#   ✓ 10 articles collected (total so far: 1100)
# [Page 397] Fetching: https://dailynews.co.tz/category/business/page/397/
#   ✓ 10 articles collected (total so far: 1110)
# [Page 398] Fetching: https://dailynews.co.tz/category/business/page/398/
#   ✓ 10 articles collected (total so far: 1120)
# [Page 399] Fetching: https://dailynews.co.tz/category/business/page/399/
#   ✓ 10 articles collected (total so far: 1130)
# [Page 400] Fetching: https://dailynews.co.tz/category/business/page/400/
#   ✓ 10 articles collected (total so far: 1140)
# 	Checkpoint saved at page 400 — 1140 records in final_news_scrape.csv
# [Page 401] Fetching: https://dailynews.co.tz/category/business/page/401/
#   ✓ 10 articles collected (total so far: 1150)
# [Page 402] Fetching: https://dailynews.co.tz/category/business/page/402/
#   ✓ 10 articles collected (total so far: 1160)
# [Page 403] Fetching: https://dailynews.co.tz/category/business/page/403/
#   ✓ 10 articles collected (total so far: 1170)
# [Page 404] Fetching: https://dailynews.co.tz/category/business/page/404/
#   ✓ 10 articles collected (total so far: 1180)
# [Page 405] Fetching: https://dailynews.co.tz/category/business/page/405/
#   ✓ 10 articles collected (total so far: 1190)
# [Page 406] Fetching: https://dailynews.co.tz/category/business/page/406/
#   ✓ 10 articles collected (total so far: 1200)
# [Page 407] Fetching: https://dailynews.co.tz/category/business/page/407/
#   ✓ 10 articles collected (total so far: 1210)
# [Page 408] Fetching: https://dailynews.co.tz/category/business/page/408/
#   ✓ 10 articles collected (total so far: 1220)
# [Page 409] Fetching: https://dailynews.co.tz/category/business/page/409/
#   ✓ 10 articles collected (total so far: 1230)
# [Page 410] Fetching: https://dailynews.co.tz/category/business/page/410/
#   ✓ 10 articles collected (total so far: 1240)
# [Page 411] Fetching: https://dailynews.co.tz/category/business/page/411/
#   ✓ 10 articles collected (total so far: 1250)
# [Page 412] Fetching: https://dailynews.co.tz/category/business/page/412/
#   ✓ 10 articles collected (total so far: 1260)
# [Page 413] Fetching: https://dailynews.co.tz/category/business/page/413/
#   ✓ 10 articles collected (total so far: 1270)
# [Page 414] Fetching: https://dailynews.co.tz/category/business/page/414/
#   ✓ 10 articles collected (total so far: 1280)
# [Page 415] Fetching: https://dailynews.co.tz/category/business/page/415/
#   ✓ 10 articles collected (total so far: 1290)
# [Page 416] Fetching: https://dailynews.co.tz/category/business/page/416/
#   ✓ 10 articles collected (total so far: 1300)
# [Page 417] Fetching: https://dailynews.co.tz/category/business/page/417/
#   ✓ 10 articles collected (total so far: 1310)
# [Page 418] Fetching: https://dailynews.co.tz/category/business/page/418/
#   ✓ 10 articles collected (total so far: 1320)
# [Page 419] Fetching: https://dailynews.co.tz/category/business/page/419/
#   ✓ 10 articles collected (total so far: 1330)
# [Page 420] Fetching: https://dailynews.co.tz/category/business/page/420/
#   ✓ 10 articles collected (total so far: 1340)
# 	Checkpoint saved at page 420 — 1340 records in final_news_scrape.csv
# [Page 421] Fetching: https://dailynews.co.tz/category/business/page/421/
#   ✓ 10 articles collected (total so far: 1350)
# [Page 422] Fetching: https://dailynews.co.tz/category/business/page/422/
#   ✓ 10 articles collected (total so far: 1360)
# [Page 423] Fetching: https://dailynews.co.tz/category/business/page/423/
#   ✓ 10 articles collected (total so far: 1370)
# [Page 424] Fetching: https://dailynews.co.tz/category/business/page/424/
#   ✓ 10 articles collected (total so far: 1380)
# [Page 425] Fetching: https://dailynews.co.tz/category/business/page/425/
#   ✓ 10 articles collected (total so far: 1390)
# [Page 426] Fetching: https://dailynews.co.tz/category/business/page/426/
#   ✓ 10 articles collected (total so far: 1400)
# [Page 427] Fetching: https://dailynews.co.tz/category/business/page/427/
#   ✓ 10 articles collected (total so far: 1410)
# [Page 428] Fetching: https://dailynews.co.tz/category/business/page/428/
#   ✓ 10 articles collected (total so far: 1420)
# [Page 429] Fetching: https://dailynews.co.tz/category/business/page/429/
#   ✓ 10 articles collected (total so far: 1430)
# [Page 430] Fetching: https://dailynews.co.tz/category/business/page/430/
#   ✓ 10 articles collected (total so far: 1440)
# [Page 431] Fetching: https://dailynews.co.tz/category/business/page/431/
#   ✓ 10 articles collected (total so far: 1450)
# [Page 432] Fetching: https://dailynews.co.tz/category/business/page/432/
#   ✓ 10 articles collected (total so far: 1460)
# [Page 433] Fetching: https://dailynews.co.tz/category/business/page/433/
#   ✓ 10 articles collected (total so far: 1470)
# [Page 434] Fetching: https://dailynews.co.tz/category/business/page/434/
#   ✓ 10 articles collected (total so far: 1480)
# [Page 435] Fetching: https://dailynews.co.tz/category/business/page/435/
#   ✓ 10 articles collected (total so far: 1490)
# [Page 436] Fetching: https://dailynews.co.tz/category/business/page/436/
#   ✓ 10 articles collected (total so far: 1500)
# [Page 437] Fetching: https://dailynews.co.tz/category/business/page/437/
#   ✓ 10 articles collected (total so far: 1510)
# [Page 438] Fetching: https://dailynews.co.tz/category/business/page/438/
#   ✓ 10 articles collected (total so far: 1520)
# [Page 439] Fetching: https://dailynews.co.tz/category/business/page/439/
#   ✓ 10 articles collected (total so far: 1530)
# [Page 440] Fetching: https://dailynews.co.tz/category/business/page/440/
#   ✓ 10 articles collected (total so far: 1540)
# 	Checkpoint saved at page 440 — 1540 records in final_news_scrape.csv
# [Page 441] Fetching: https://dailynews.co.tz/category/business/page/441/
#   ✓ 10 articles collected (total so far: 1550)
# [Page 442] Fetching: https://dailynews.co.tz/category/business/page/442/
#   ✓ 10 articles collected (total so far: 1560)
# [Page 443] Fetching: https://dailynews.co.tz/category/business/page/443/
#   ✓ 10 articles collected (total so far: 1570)
# [Page 444] Fetching: https://dailynews.co.tz/category/business/page/444/
#   ✓ 10 articles collected (total so far: 1580)
# [Page 445] Fetching: https://dailynews.co.tz/category/business/page/445/
#   ✓ 10 articles collected (total so far: 1590)
# [Page 446] Fetching: https://dailynews.co.tz/category/business/page/446/
#   ✓ 10 articles collected (total so far: 1600)
# [Page 447] Fetching: https://dailynews.co.tz/category/business/page/447/
#   ✓ 10 articles collected (total so far: 1610)
# [Page 448] Fetching: https://dailynews.co.tz/category/business/page/448/
#   ✓ 10 articles collected (total so far: 1620)
# [Page 449] Fetching: https://dailynews.co.tz/category/business/page/449/
#   ✓ 10 articles collected (total so far: 1630)
# [Page 450] Fetching: https://dailynews.co.tz/category/business/page/450/
#   ✓ 10 articles collected (total so far: 1640)
# [Page 451] Fetching: https://dailynews.co.tz/category/business/page/451/
#   ✓ 10 articles collected (total so far: 1650)
# [Page 452] Fetching: https://dailynews.co.tz/category/business/page/452/
#   ✓ 10 articles collected (total so far: 1660)
# [Page 453] Fetching: https://dailynews.co.tz/category/business/page/453/
#   ✓ 10 articles collected (total so far: 1670)
# [Page 454] Fetching: https://dailynews.co.tz/category/business/page/454/
#   ✓ 10 articles collected (total so far: 1680)
# [Page 455] Fetching: https://dailynews.co.tz/category/business/page/455/
#   ✓ 10 articles collected (total so far: 1690)
# [Page 456] Fetching: https://dailynews.co.tz/category/business/page/456/
#   ✓ 10 articles collected (total so far: 1700)
# [Page 457] Fetching: https://dailynews.co.tz/category/business/page/457/
#   ✓ 10 articles collected (total so far: 1710)
# [Page 458] Fetching: https://dailynews.co.tz/category/business/page/458/
#   ✓ 10 articles collected (total so far: 1720)
# [Page 459] Fetching: https://dailynews.co.tz/category/business/page/459/
#   ✓ 10 articles collected (total so far: 1730)
# [Page 460] Fetching: https://dailynews.co.tz/category/business/page/460/
#   ✓ 10 articles collected (total so far: 1740)
# 	Checkpoint saved at page 460 — 1740 records in final_news_scrape.csv
# [Page 461] Fetching: https://dailynews.co.tz/category/business/page/461/
#   ✓ 10 articles collected (total so far: 1750)
# [Page 462] Fetching: https://dailynews.co.tz/category/business/page/462/
#   ✓ 10 articles collected (total so far: 1760)
# [Page 463] Fetching: https://dailynews.co.tz/category/business/page/463/
#   ✓ 10 articles collected (total so far: 1770)
# [Page 464] Fetching: https://dailynews.co.tz/category/business/page/464/
#   ✓ 10 articles collected (total so far: 1780)
# [Page 465] Fetching: https://dailynews.co.tz/category/business/page/465/
#   ✓ 10 articles collected (total so far: 1790)
# [Page 466] Fetching: https://dailynews.co.tz/category/business/page/466/
#   ✓ 10 articles collected (total so far: 1800)
# [Page 467] Fetching: https://dailynews.co.tz/category/business/page/467/
#   ✓ 10 articles collected (total so far: 1810)
# [Page 468] Fetching: https://dailynews.co.tz/category/business/page/468/
#   ✓ 10 articles collected (total so far: 1820)
# [Page 469] Fetching: https://dailynews.co.tz/category/business/page/469/
#   ✓ 10 articles collected (total so far: 1830)
# [Page 470] Fetching: https://dailynews.co.tz/category/business/page/470/
#   ✓ 10 articles collected (total so far: 1840)
# [Page 471] Fetching: https://dailynews.co.tz/category/business/page/471/
#   ✓ 10 articles collected (total so far: 1850)
# [Page 472] Fetching: https://dailynews.co.tz/category/business/page/472/
#   ✓ 10 articles collected (total so far: 1860)
# [Page 473] Fetching: https://dailynews.co.tz/category/business/page/473/
#   ✓ 10 articles collected (total so far: 1870)
# [Page 474] Fetching: https://dailynews.co.tz/category/business/page/474/
#   ✓ 10 articles collected (total so far: 1880)
# [Page 475] Fetching: https://dailynews.co.tz/category/business/page/475/
#   ✓ 10 articles collected (total so far: 1890)
# [Page 476] Fetching: https://dailynews.co.tz/category/business/page/476/
#   ✓ 10 articles collected (total so far: 1900)
# [Page 477] Fetching: https://dailynews.co.tz/category/business/page/477/
#   ✓ 10 articles collected (total so far: 1910)
# [Page 478] Fetching: https://dailynews.co.tz/category/business/page/478/
#   ✓ 10 articles collected (total so far: 1920)
# [Page 479] Fetching: https://dailynews.co.tz/category/business/page/479/
#   ✓ 10 articles collected (total so far: 1930)
# [Page 480] Fetching: https://dailynews.co.tz/category/business/page/480/
#   ✓ 10 articles collected (total so far: 1940)
# 	Checkpoint saved at page 480 — 1940 records in final_news_scrape.csv
# [Page 481] Fetching: https://dailynews.co.tz/category/business/page/481/
#   ✓ 10 articles collected (total so far: 1950)
# [Page 482] Fetching: https://dailynews.co.tz/category/business/page/482/
#   ✓ 10 articles collected (total so far: 1960)
# [Page 483] Fetching: https://dailynews.co.tz/category/business/page/483/
#   ✓ 10 articles collected (total so far: 1970)
# [Page 484] Fetching: https://dailynews.co.tz/category/business/page/484/
#   ✓ 10 articles collected (total so far: 1980)
# [Page 485] Fetching: https://dailynews.co.tz/category/business/page/485/
#   ✓ 10 articles collected (total so far: 1990)
# [Page 486] Fetching: https://dailynews.co.tz/category/business/page/486/
#   ✓ 10 articles collected (total so far: 2000)
# [Page 487] Fetching: https://dailynews.co.tz/category/business/page/487/
#   ✓ 10 articles collected (total so far: 2010)
# [Page 488] Fetching: https://dailynews.co.tz/category/business/page/488/
#   ✓ 10 articles collected (total so far: 2020)
# [Page 489] Fetching: https://dailynews.co.tz/category/business/page/489/
#   ✓ 10 articles collected (total so far: 2030)
# [Page 490] Fetching: https://dailynews.co.tz/category/business/page/490/
#   ✓ 10 articles collected (total so far: 2040)
# [Page 491] Fetching: https://dailynews.co.tz/category/business/page/491/
#   ✓ 10 articles collected (total so far: 2050)
# [Page 492] Fetching: https://dailynews.co.tz/category/business/page/492/
#   ✓ 10 articles collected (total so far: 2060)
# [Page 493] Fetching: https://dailynews.co.tz/category/business/page/493/
#   ✓ 10 articles collected (total so far: 2070)
# [Page 494] Fetching: https://dailynews.co.tz/category/business/page/494/
#   ✓ 10 articles collected (total so far: 2080)
# [Page 495] Fetching: https://dailynews.co.tz/category/business/page/495/
#   ✓ 10 articles collected (total so far: 2090)
# [Page 496] Fetching: https://dailynews.co.tz/category/business/page/496/
#   ✓ 10 articles collected (total so far: 2100)
# [Page 497] Fetching: https://dailynews.co.tz/category/business/page/497/
#   ✓ 10 articles collected (total so far: 2110)
# [Page 498] Fetching: https://dailynews.co.tz/category/business/page/498/
#   ✓ 10 articles collected (total so far: 2120)
# [Page 499] Fetching: https://dailynews.co.tz/category/business/page/499/
#   ✓ 10 articles collected (total so far: 2130)
# [Page 500] Fetching: https://dailynews.co.tz/category/business/page/500/
#   ✓ 10 articles collected (total so far: 2140)
# 	Checkpoint saved at page 500 — 2140 records in final_news_scrape.csv
# [Page 501] Fetching: https://dailynews.co.tz/category/business/page/501/
#   ✓ 10 articles collected (total so far: 2150)
# [Page 502] Fetching: https://dailynews.co.tz/category/business/page/502/
#   ✓ 10 articles collected (total so far: 2160)
# [Page 503] Fetching: https://dailynews.co.tz/category/business/page/503/
#   ✓ 10 articles collected (total so far: 2170)
# [Page 504] Fetching: https://dailynews.co.tz/category/business/page/504/
#   ✓ 10 articles collected (total so far: 2180)
# [Page 505] Fetching: https://dailynews.co.tz/category/business/page/505/
#   ✓ 10 articles collected (total so far: 2190)
# [Page 506] Fetching: https://dailynews.co.tz/category/business/page/506/
#   ✓ 10 articles collected (total so far: 2200)
# [Page 507] Fetching: https://dailynews.co.tz/category/business/page/507/
#   ✓ 10 articles collected (total so far: 2210)
# [Page 508] Fetching: https://dailynews.co.tz/category/business/page/508/
#   ✓ 10 articles collected (total so far: 2220)
# [Page 509] Fetching: https://dailynews.co.tz/category/business/page/509/
#   ✓ 10 articles collected (total so far: 2230)
# [Page 510] Fetching: https://dailynews.co.tz/category/business/page/510/
#   ✓ 10 articles collected (total so far: 2240)
# [Page 511] Fetching: https://dailynews.co.tz/category/business/page/511/
#   ✓ 10 articles collected (total so far: 2250)
# [Page 512] Fetching: https://dailynews.co.tz/category/business/page/512/
#   ✓ 10 articles collected (total so far: 2260)
# [Page 513] Fetching: https://dailynews.co.tz/category/business/page/513/
#   ✓ 10 articles collected (total so far: 2270)
# [Page 514] Fetching: https://dailynews.co.tz/category/business/page/514/
#   ✓ 10 articles collected (total so far: 2280)
# [Page 515] Fetching: https://dailynews.co.tz/category/business/page/515/
#   ✓ 10 articles collected (total so far: 2290)
# [Page 516] Fetching: https://dailynews.co.tz/category/business/page/516/
#   ✓ 10 articles collected (total so far: 2300)
# [Page 517] Fetching: https://dailynews.co.tz/category/business/page/517/
#   ⚠ WARNING: Could not load page 517 — skipping
#     Reason: 500 Server Error: Internal Server Error for url: https://dailynews.co.tz/category/business/page/517/
#
# [Page 518] Fetching: https://dailynews.co.tz/category/business/page/518/
#   ✓ 10 articles collected (total so far: 2310)
# [Page 519] Fetching: https://dailynews.co.tz/category/business/page/519/
#   ✓ 10 articles collected (total so far: 2320)
# [Page 520] Fetching: https://dailynews.co.tz/category/business/page/520/
#   ✓ 10 articles collected (total so far: 2330)
# 	Checkpoint saved at page 520 — 2330 records in final_news_scrape.csv
# [Page 521] Fetching: https://dailynews.co.tz/category/business/page/521/
#   ✓ 10 articles collected (total so far: 2340)
# [Page 522] Fetching: https://dailynews.co.tz/category/business/page/522/
#   ✓ 10 articles collected (total so far: 2350)
# [Page 523] Fetching: https://dailynews.co.tz/category/business/page/523/
#   ✓ 10 articles collected (total so far: 2360)
# [Page 524] Fetching: https://dailynews.co.tz/category/business/page/524/
#   ✓ 10 articles collected (total so far: 2370)
# [Page 525] Fetching: https://dailynews.co.tz/category/business/page/525/
#   ✓ 10 articles collected (total so far: 2380)
# [Page 526] Fetching: https://dailynews.co.tz/category/business/page/526/
#   ✓ 10 articles collected (total so far: 2390)
# [Page 527] Fetching: https://dailynews.co.tz/category/business/page/527/
#   ✓ 10 articles collected (total so far: 2400)
# [Page 528] Fetching: https://dailynews.co.tz/category/business/page/528/
#   ✓ 10 articles collected (total so far: 2410)
# [Page 529] Fetching: https://dailynews.co.tz/category/business/page/529/
#   ✓ 10 articles collected (total so far: 2420)
# [Page 530] Fetching: https://dailynews.co.tz/category/business/page/530/
#   ✓ 10 articles collected (total so far: 2430)
# [Page 531] Fetching: https://dailynews.co.tz/category/business/page/531/
#   ✓ 10 articles collected (total so far: 2440)
# [Page 532] Fetching: https://dailynews.co.tz/category/business/page/532/
#   ✓ 10 articles collected (total so far: 2450)
# [Page 533] Fetching: https://dailynews.co.tz/category/business/page/533/
#   ✓ 10 articles collected (total so far: 2460)
# [Page 534] Fetching: https://dailynews.co.tz/category/business/page/534/
#   ✓ 10 articles collected (total so far: 2470)
# [Page 535] Fetching: https://dailynews.co.tz/category/business/page/535/
#   ✓ 10 articles collected (total so far: 2480)
# [Page 536] Fetching: https://dailynews.co.tz/category/business/page/536/
#   ✓ 10 articles collected (total so far: 2490)
# [Page 537] Fetching: https://dailynews.co.tz/category/business/page/537/
#   ✓ 10 articles collected (total so far: 2500)
# [Page 538] Fetching: https://dailynews.co.tz/category/business/page/538/
#   ✓ 10 articles collected (total so far: 2510)
# [Page 539] Fetching: https://dailynews.co.tz/category/business/page/539/
#   ✓ 10 articles collected (total so far: 2520)
# [Page 540] Fetching: https://dailynews.co.tz/category/business/page/540/
#   ✓ 10 articles collected (total so far: 2530)
# 	Checkpoint saved at page 540 — 2530 records in final_news_scrape.csv
# [Page 541] Fetching: https://dailynews.co.tz/category/business/page/541/
#   ✓ 10 articles collected (total so far: 2540)
# [Page 542] Fetching: https://dailynews.co.tz/category/business/page/542/
#   ✓ 10 articles collected (total so far: 2550)
# [Page 543] Fetching: https://dailynews.co.tz/category/business/page/543/
#   ✓ 10 articles collected (total so far: 2560)
# [Page 544] Fetching: https://dailynews.co.tz/category/business/page/544/
#   ✓ 10 articles collected (total so far: 2570)
# [Page 545] Fetching: https://dailynews.co.tz/category/business/page/545/
#   ✓ 10 articles collected (total so far: 2580)
# [Page 546] Fetching: https://dailynews.co.tz/category/business/page/546/
#   ✓ 10 articles collected (total so far: 2590)
# [Page 547] Fetching: https://dailynews.co.tz/category/business/page/547/
#   ✓ 10 articles collected (total so far: 2600)
# [Page 548] Fetching: https://dailynews.co.tz/category/business/page/548/
#   ✓ 10 articles collected (total so far: 2610)
# [Page 549] Fetching: https://dailynews.co.tz/category/business/page/549/
#   ✓ 10 articles collected (total so far: 2620)
# [Page 550] Fetching: https://dailynews.co.tz/category/business/page/550/
#   ✓ 10 articles collected (total so far: 2630)
# [Page 551] Fetching: https://dailynews.co.tz/category/business/page/551/
#   ✓ 10 articles collected (total so far: 2640)
# [Page 552] Fetching: https://dailynews.co.tz/category/business/page/552/
#   ✓ 10 articles collected (total so far: 2650)
# [Page 553] Fetching: https://dailynews.co.tz/category/business/page/553/
#   ✓ 10 articles collected (total so far: 2660)
# [Page 554] Fetching: https://dailynews.co.tz/category/business/page/554/
#   ✓ 10 articles collected (total so far: 2670)
# [Page 555] Fetching: https://dailynews.co.tz/category/business/page/555/
#   ✓ 10 articles collected (total so far: 2680)
# [Page 556] Fetching: https://dailynews.co.tz/category/business/page/556/
#   ✓ 10 articles collected (total so far: 2690)
# [Page 557] Fetching: https://dailynews.co.tz/category/business/page/557/
#   ✓ 10 articles collected (total so far: 2700)
# [Page 558] Fetching: https://dailynews.co.tz/category/business/page/558/
#   ✓ 10 articles collected (total so far: 2710)
# [Page 559] Fetching: https://dailynews.co.tz/category/business/page/559/
#   ✓ 10 articles collected (total so far: 2720)
# [Page 560] Fetching: https://dailynews.co.tz/category/business/page/560/
#   ✓ 10 articles collected (total so far: 2730)
# 	Checkpoint saved at page 560 — 2730 records in final_news_scrape.csv
# [Page 561] Fetching: https://dailynews.co.tz/category/business/page/561/
#   ✓ 10 articles collected (total so far: 2740)
# [Page 562] Fetching: https://dailynews.co.tz/category/business/page/562/
#   ✓ 10 articles collected (total so far: 2750)
# [Page 563] Fetching: https://dailynews.co.tz/category/business/page/563/
#   ✓ 10 articles collected (total so far: 2760)
# [Page 564] Fetching: https://dailynews.co.tz/category/business/page/564/
#   ✓ 10 articles collected (total so far: 2770)
# [Page 565] Fetching: https://dailynews.co.tz/category/business/page/565/
#   ✓ 10 articles collected (total so far: 2780)
# [Page 566] Fetching: https://dailynews.co.tz/category/business/page/566/
#   ✓ 10 articles collected (total so far: 2790)
# [Page 567] Fetching: https://dailynews.co.tz/category/business/page/567/
#   ✓ 10 articles collected (total so far: 2800)
# [Page 568] Fetching: https://dailynews.co.tz/category/business/page/568/
#   ✓ 10 articles collected (total so far: 2810)
# [Page 569] Fetching: https://dailynews.co.tz/category/business/page/569/
#   ✓ 10 articles collected (total so far: 2820)
# [Page 570] Fetching: https://dailynews.co.tz/category/business/page/570/
#   ✓ 10 articles collected (total so far: 2830)
# [Page 571] Fetching: https://dailynews.co.tz/category/business/page/571/
#   ✓ 10 articles collected (total so far: 2840)
# [Page 572] Fetching: https://dailynews.co.tz/category/business/page/572/
#   ✓ 10 articles collected (total so far: 2850)
# [Page 573] Fetching: https://dailynews.co.tz/category/business/page/573/
#   ✓ 10 articles collected (total so far: 2860)
# [Page 574] Fetching: https://dailynews.co.tz/category/business/page/574/
#   ✓ 10 articles collected (total so far: 2870)
# [Page 575] Fetching: https://dailynews.co.tz/category/business/page/575/
#   ✓ 10 articles collected (total so far: 2880)
# [Page 576] Fetching: https://dailynews.co.tz/category/business/page/576/
#   ✓ 10 articles collected (total so far: 2890)
# [Page 577] Fetching: https://dailynews.co.tz/category/business/page/577/
#   ✓ 10 articles collected (total so far: 2900)
# [Page 578] Fetching: https://dailynews.co.tz/category/business/page/578/
#   ✓ 10 articles collected (total so far: 2910)
# [Page 579] Fetching: https://dailynews.co.tz/category/business/page/579/
#   ✓ 10 articles collected (total so far: 2920)
# [Page 580] Fetching: https://dailynews.co.tz/category/business/page/580/
#   ✓ 10 articles collected (total so far: 2930)
# 	Checkpoint saved at page 580 — 2930 records in final_news_scrape.csv
# [Page 581] Fetching: https://dailynews.co.tz/category/business/page/581/
#   ✓ 10 articles collected (total so far: 2940)
# [Page 582] Fetching: https://dailynews.co.tz/category/business/page/582/
#   ✓ 10 articles collected (total so far: 2950)
# [Page 583] Fetching: https://dailynews.co.tz/category/business/page/583/
#   ✓ 10 articles collected (total so far: 2960)
# [Page 584] Fetching: https://dailynews.co.tz/category/business/page/584/
#   ✓ 10 articles collected (total so far: 2970)
# [Page 585] Fetching: https://dailynews.co.tz/category/business/page/585/
#   ✓ 10 articles collected (total so far: 2980)
# [Page 586] Fetching: https://dailynews.co.tz/category/business/page/586/
#   ✓ 10 articles collected (total so far: 2990)
# [Page 587] Fetching: https://dailynews.co.tz/category/business/page/587/
#   ✓ 10 articles collected (total so far: 3000)
# [Page 588] Fetching: https://dailynews.co.tz/category/business/page/588/
#   ✓ 10 articles collected (total so far: 3010)
# [Page 589] Fetching: https://dailynews.co.tz/category/business/page/589/
#   ✓ 10 articles collected (total so far: 3020)
# [Page 590] Fetching: https://dailynews.co.tz/category/business/page/590/
#   ✓ 10 articles collected (total so far: 3030)
# [Page 591] Fetching: https://dailynews.co.tz/category/business/page/591/
#   ✓ 10 articles collected (total so far: 3040)
# [Page 592] Fetching: https://dailynews.co.tz/category/business/page/592/
#   ✓ 10 articles collected (total so far: 3050)
# [Page 593] Fetching: https://dailynews.co.tz/category/business/page/593/
#   ✓ 10 articles collected (total so far: 3060)
# [Page 594] Fetching: https://dailynews.co.tz/category/business/page/594/
#   ✓ 10 articles collected (total so far: 3070)
# [Page 595] Fetching: https://dailynews.co.tz/category/business/page/595/
#   ✓ 10 articles collected (total so far: 3080)
# [Page 596] Fetching: https://dailynews.co.tz/category/business/page/596/
#   ✓ 10 articles collected (total so far: 3090)
# [Page 597] Fetching: https://dailynews.co.tz/category/business/page/597/
#   ✓ 10 articles collected (total so far: 3100)
# [Page 598] Fetching: https://dailynews.co.tz/category/business/page/598/
#   ✓ 10 articles collected (total so far: 3110)
# [Page 599] Fetching: https://dailynews.co.tz/category/business/page/599/
#   ✓ 10 articles collected (total so far: 3120)
# [Page 600] Fetching: https://dailynews.co.tz/category/business/page/600/
#   ✓ 10 articles collected (total so far: 3130)
# 	Checkpoint saved at page 600 — 3130 records in final_news_scrape.csv
# [Page 601] Fetching: https://dailynews.co.tz/category/business/page/601/
#   ✓ 10 articles collected (total so far: 3140)
# [Page 602] Fetching: https://dailynews.co.tz/category/business/page/602/
#   ✓ 10 articles collected (total so far: 3150)
# [Page 603] Fetching: https://dailynews.co.tz/category/business/page/603/
#   ✓ 10 articles collected (total so far: 3160)
# [Page 604] Fetching: https://dailynews.co.tz/category/business/page/604/
#   ✓ 10 articles collected (total so far: 3170)
# [Page 605] Fetching: https://dailynews.co.tz/category/business/page/605/
#   ✓ 10 articles collected (total so far: 3180)
# [Page 606] Fetching: https://dailynews.co.tz/category/business/page/606/
#   ✓ 10 articles collected (total so far: 3190)
# [Page 607] Fetching: https://dailynews.co.tz/category/business/page/607/
#   ✓ 10 articles collected (total so far: 3200)
# [Page 608] Fetching: https://dailynews.co.tz/category/business/page/608/
#   ✓ 10 articles collected (total so far: 3210)
# [Page 609] Fetching: https://dailynews.co.tz/category/business/page/609/
#   ✓ 10 articles collected (total so far: 3220)
# [Page 610] Fetching: https://dailynews.co.tz/category/business/page/610/
#   ✓ 10 articles collected (total so far: 3230)
# [Page 611] Fetching: https://dailynews.co.tz/category/business/page/611/
#   ✓ 10 articles collected (total so far: 3240)
# [Page 612] Fetching: https://dailynews.co.tz/category/business/page/612/
#   ✓ 10 articles collected (total so far: 3250)
# [Page 613] Fetching: https://dailynews.co.tz/category/business/page/613/
#   ✓ 10 articles collected (total so far: 3260)
# [Page 614] Fetching: https://dailynews.co.tz/category/business/page/614/
#   ✓ 10 articles collected (total so far: 3270)
# [Page 615] Fetching: https://dailynews.co.tz/category/business/page/615/
#   ✓ 10 articles collected (total so far: 3280)
# [Page 616] Fetching: https://dailynews.co.tz/category/business/page/616/
#   ✓ 10 articles collected (total so far: 3290)
# [Page 617] Fetching: https://dailynews.co.tz/category/business/page/617/
#   ✓ 10 articles collected (total so far: 3300)
# [Page 618] Fetching: https://dailynews.co.tz/category/business/page/618/
#   ✓ 10 articles collected (total so far: 3310)
# [Page 619] Fetching: https://dailynews.co.tz/category/business/page/619/
#   ✓ 10 articles collected (total so far: 3320)
# [Page 620] Fetching: https://dailynews.co.tz/category/business/page/620/
#   ✓ 10 articles collected (total so far: 3330)
# 	Checkpoint saved at page 620 — 3330 records in final_news_scrape.csv
# [Page 621] Fetching: https://dailynews.co.tz/category/business/page/621/
#   ✓ 10 articles collected (total so far: 3340)
# [Page 622] Fetching: https://dailynews.co.tz/category/business/page/622/
#   ✓ 10 articles collected (total so far: 3350)
# [Page 623] Fetching: https://dailynews.co.tz/category/business/page/623/
#   ✓ 10 articles collected (total so far: 3360)
# [Page 624] Fetching: https://dailynews.co.tz/category/business/page/624/
#   ✓ 10 articles collected (total so far: 3370)
# [Page 625] Fetching: https://dailynews.co.tz/category/business/page/625/
#   ✓ 10 articles collected (total so far: 3380)
# [Page 626] Fetching: https://dailynews.co.tz/category/business/page/626/
#   ✓ 10 articles collected (total so far: 3390)
# [Page 627] Fetching: https://dailynews.co.tz/category/business/page/627/
#   ✓ 10 articles collected (total so far: 3400)
# [Page 628] Fetching: https://dailynews.co.tz/category/business/page/628/
#   ✓ 10 articles collected (total so far: 3410)
# [Page 629] Fetching: https://dailynews.co.tz/category/business/page/629/
#   ✓ 10 articles collected (total so far: 3420)
# [Page 630] Fetching: https://dailynews.co.tz/category/business/page/630/
#   ✓ 10 articles collected (total so far: 3430)
# [Page 631] Fetching: https://dailynews.co.tz/category/business/page/631/
#   ✓ 10 articles collected (total so far: 3440)
# [Page 632] Fetching: https://dailynews.co.tz/category/business/page/632/
#   ✓ 10 articles collected (total so far: 3450)
# [Page 633] Fetching: https://dailynews.co.tz/category/business/page/633/
#   ✓ 10 articles collected (total so far: 3460)
# [Page 634] Fetching: https://dailynews.co.tz/category/business/page/634/
#   ✓ 10 articles collected (total so far: 3470)
# [Page 635] Fetching: https://dailynews.co.tz/category/business/page/635/
#   ✓ 10 articles collected (total so far: 3480)
# [Page 636] Fetching: https://dailynews.co.tz/category/business/page/636/
#   ✓ 10 articles collected (total so far: 3490)
# [Page 637] Fetching: https://dailynews.co.tz/category/business/page/637/
#   ✓ 10 articles collected (total so far: 3500)
# [Page 638] Fetching: https://dailynews.co.tz/category/business/page/638/
#   ✓ 10 articles collected (total so far: 3510)
# [Page 639] Fetching: https://dailynews.co.tz/category/business/page/639/
#   ✓ 10 articles collected (total so far: 3520)
# [Page 640] Fetching: https://dailynews.co.tz/category/business/page/640/
#   ✓ 10 articles collected (total so far: 3530)
# 	Checkpoint saved at page 640 — 3530 records in final_news_scrape.csv
# [Page 641] Fetching: https://dailynews.co.tz/category/business/page/641/
#   ✓ 10 articles collected (total so far: 3540)
# [Page 642] Fetching: https://dailynews.co.tz/category/business/page/642/
#   ✓ 10 articles collected (total so far: 3550)
# [Page 643] Fetching: https://dailynews.co.tz/category/business/page/643/
#   ✓ 10 articles collected (total so far: 3560)
# [Page 644] Fetching: https://dailynews.co.tz/category/business/page/644/
#   ✓ 10 articles collected (total so far: 3570)
# [Page 645] Fetching: https://dailynews.co.tz/category/business/page/645/
#   ✓ 10 articles collected (total so far: 3580)
# [Page 646] Fetching: https://dailynews.co.tz/category/business/page/646/
#   ✓ 10 articles collected (total so far: 3590)
# [Page 647] Fetching: https://dailynews.co.tz/category/business/page/647/
#   ✓ 10 articles collected (total so far: 3600)
# [Page 648] Fetching: https://dailynews.co.tz/category/business/page/648/
#   ✓ 10 articles collected (total so far: 3610)
# [Page 649] Fetching: https://dailynews.co.tz/category/business/page/649/
#   ✓ 10 articles collected (total so far: 3620)
# [Page 650] Fetching: https://dailynews.co.tz/category/business/page/650/
#   ✓ 10 articles collected (total so far: 3630)
# [Page 651] Fetching: https://dailynews.co.tz/category/business/page/651/
#   ✓ 10 articles collected (total so far: 3640)
# [Page 652] Fetching: https://dailynews.co.tz/category/business/page/652/
#   ✓ 10 articles collected (total so far: 3650)
# [Page 653] Fetching: https://dailynews.co.tz/category/business/page/653/
#   ✓ 10 articles collected (total so far: 3660)
# [Page 654] Fetching: https://dailynews.co.tz/category/business/page/654/
#   ✓ 10 articles collected (total so far: 3670)
# [Page 655] Fetching: https://dailynews.co.tz/category/business/page/655/
#   ✓ 10 articles collected (total so far: 3680)
# [Page 656] Fetching: https://dailynews.co.tz/category/business/page/656/
#   ✓ 10 articles collected (total so far: 3690)
# [Page 657] Fetching: https://dailynews.co.tz/category/business/page/657/
#   ✓ 10 articles collected (total so far: 3700)
# [Page 658] Fetching: https://dailynews.co.tz/category/business/page/658/
#   ✓ 10 articles collected (total so far: 3710)
# [Page 659] Fetching: https://dailynews.co.tz/category/business/page/659/
#   ✓ 10 articles collected (total so far: 3720)
# [Page 660] Fetching: https://dailynews.co.tz/category/business/page/660/
#   ✓ 10 articles collected (total so far: 3730)
# 	Checkpoint saved at page 660 — 3730 records in final_news_scrape.csv
# [Page 661] Fetching: https://dailynews.co.tz/category/business/page/661/
#   ✓ 10 articles collected (total so far: 3740)
# [Page 662] Fetching: https://dailynews.co.tz/category/business/page/662/
#   ✓ 10 articles collected (total so far: 3750)
# [Page 663] Fetching: https://dailynews.co.tz/category/business/page/663/
#   ✓ 10 articles collected (total so far: 3760)
# [Page 664] Fetching: https://dailynews.co.tz/category/business/page/664/
#   ✓ 10 articles collected (total so far: 3770)
# [Page 665] Fetching: https://dailynews.co.tz/category/business/page/665/
#   ✓ 10 articles collected (total so far: 3780)
# [Page 666] Fetching: https://dailynews.co.tz/category/business/page/666/
#   ✓ 10 articles collected (total so far: 3790)
# [Page 667] Fetching: https://dailynews.co.tz/category/business/page/667/
#   ✓ 10 articles collected (total so far: 3800)
# [Page 668] Fetching: https://dailynews.co.tz/category/business/page/668/
#   ✓ 10 articles collected (total so far: 3810)
# [Page 669] Fetching: https://dailynews.co.tz/category/business/page/669/
#   ✓ 10 articles collected (total so far: 3820)
# [Page 670] Fetching: https://dailynews.co.tz/category/business/page/670/
#   ✓ 10 articles collected (total so far: 3830)
# [Page 671] Fetching: https://dailynews.co.tz/category/business/page/671/
#   ✓ 10 articles collected (total so far: 3840)
# [Page 672] Fetching: https://dailynews.co.tz/category/business/page/672/
#   ✓ 10 articles collected (total so far: 3850)
# [Page 673] Fetching: https://dailynews.co.tz/category/business/page/673/
#   ✓ 10 articles collected (total so far: 3860)
# [Page 674] Fetching: https://dailynews.co.tz/category/business/page/674/
#   ✓ 10 articles collected (total so far: 3870)
# [Page 675] Fetching: https://dailynews.co.tz/category/business/page/675/
#   ✓ 10 articles collected (total so far: 3880)
# [Page 676] Fetching: https://dailynews.co.tz/category/business/page/676/
#   ✓ 10 articles collected (total so far: 3890)
# [Page 677] Fetching: https://dailynews.co.tz/category/business/page/677/
#   ✓ 10 articles collected (total so far: 3900)
# [Page 678] Fetching: https://dailynews.co.tz/category/business/page/678/
#   ✓ 10 articles collected (total so far: 3910)
# [Page 679] Fetching: https://dailynews.co.tz/category/business/page/679/
#   ✓ 10 articles collected (total so far: 3920)
# [Page 680] Fetching: https://dailynews.co.tz/category/business/page/680/
#   ✓ 10 articles collected (total so far: 3930)
# 	Checkpoint saved at page 680 — 3930 records in final_news_scrape.csv
# [Page 681] Fetching: https://dailynews.co.tz/category/business/page/681/
#   ✓ 10 articles collected (total so far: 3940)
# [Page 682] Fetching: https://dailynews.co.tz/category/business/page/682/
#   ✓ 10 articles collected (total so far: 3950)
# [Page 683] Fetching: https://dailynews.co.tz/category/business/page/683/
#   ✓ 9 articles collected (total so far: 3959)
#
# 	Final save: 29 remaining records written
#
#
# =======================================================
#   ✓ Scrape complete!
#   Total headlines saved : 3959
#   File                  : final_news_scrape.csv
# =======================================================

# %%
SITE        = DAILY_NEWS          # ← swap to THE_CITIZEN or any other config
START_PAGE  = 287                 # ← first page of your target date range
END_PAGE    = 683                 # ← last page of your target date range
OUTPUT_FILE = 'dailynews_headlines_2022_2024.csv'

# ── To resume after a crash, update START_PAGE to where it stopped ──
# START_PAGE = 450   # example: resume from page 450

print(f"Ready to scrape: {SITE['name']}")
print(f"Pages          : {START_PAGE} → {END_PAGE}")
print(f"Output file    : {OUTPUT_FILE}")

# %%
# ── Start scraping ──
# scrape_site(SITE, START_PAGE, END_PAGE, OUTPUT_FILE)

print("⚠️  Uncomment the line above once functions in Section 4 are defined")

# %% [markdown]
# ---
# ## Section 6 — Results Preview
#
# Once scraping is complete, run the cells below to inspect and clean your dataset.

# %%
# ── Load and preview the collected dataset ──
df = pd.read_csv(OUTPUT_FILE)

print(f"Total rows collected : {len(df)}")
print(f"Columns              : {list(df.columns)}")
print(f"\nDate range           : {df['date'].min()} → {df['date'].max()}")

# %%
# ── Year distribution ──
df['year'] = df['date'].str[:4]
print("Articles per year:")
print(df['year'].value_counts().sort_index())

# %%
# ── Remove duplicates ──
before = len(df)
df = df.drop_duplicates(subset='url')
after  = len(df)
print(f"Duplicates removed: {before - after}")
print(f"Clean dataset size: {after} articles")

df.to_csv(OUTPUT_FILE, index=False)
print(f"\n✓ Saved clean dataset to {OUTPUT_FILE}")

# %%
# ── Sample headlines ──
df.sample(10)[['date', 'headline', 'source']]

# %% [markdown]
# ---
# ## Section 7 — Next Steps
#
# With your headlines dataset ready, the next notebooks in this project will cover:
#
# 1. **Sentiment Analysis** — label each headline as Positive / Negative / Neutral
#    using a pre-trained model (e.g. VADER or a fine-tuned transformer)
#
# 2. **Financial Data Collection** — download TZS/USD exchange rates from the
#    Bank of Tanzania (`bot.go.tz`) and CPI/inflation data from NBS Tanzania (`nbs.go.tz`)
#
# 3. **Correlation Analysis** — merge sentiment scores with financial indicators
#    and analyse whether news tone correlates with currency or inflation movements
#
# 4. **Visualisation & Reporting** — charts, heatmaps, and summary statistics
#    for the final project report
#
# ---
# *Tanzania Financial News Scraper — DS & AI Year I Project*
